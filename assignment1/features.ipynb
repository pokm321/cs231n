# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = "cs231n/assignment1/"
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %%
X_train.shape
# Out:
# (49000, 32, 32, 3)

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from cs231n.classifiers import LinearSVM

verbose = True

for lr in learning_rates:
  for rs in regularization_strengths:
    svm = LinearSVM() # 초기화
    loss_hist = svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs,
                          num_iters=200, verbose=verbose) # train

    y_train_pred = svm.predict(X_train_feats)
    train_accuracy = np.mean(y_train == y_train_pred)
    y_val_pred = svm.predict(X_val_feats)
    val_accuracy = np.mean(y_val == y_val_pred)

    results[(lr,rs)] = (train_accuracy, val_accuracy)

    if val_accuracy > best_val:
      best_val = val_accuracy
      best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# ---------- 1.0e-09 5.0e+04 ----------
# iteration 0 / 200: loss 85.435237
# iteration 100 / 200: loss 83.917034
# iteration 199 / 200: loss 82.459972
#
# ---------- 1.0e-09 5.0e+05 ----------
# iteration 0 / 200: loss 766.310672
# iteration 100 / 200: loss 628.981355
# iteration 199 / 200: loss 517.565614
#
# ---------- 1.0e-09 5.0e+06 ----------
# iteration 0 / 200: loss 8544.281426
# iteration 100 / 200: loss 1152.556501
# iteration 199 / 200: loss 165.322886
#
# ---------- 1.0e-08 5.0e+04 ----------
# iteration 0 / 200: loss 87.931600
# iteration 100 / 200: loss 73.596331
# iteration 199 / 200: loss 61.990681
#
# ---------- 1.0e-08 5.0e+05 ----------
# iteration 0 / 200: loss 828.155360
# iteration 100 / 200: loss 118.746343
# iteration 199 / 200: loss 24.003782
#
# ---------- 1.0e-08 5.0e+06 ----------
# iteration 0 / 200: loss 7542.718903
# iteration 100 / 200: loss 9.000003
# iteration 199 / 200: loss 8.999998
#
# ---------- 1.0e-07 5.0e+04 ----------
# iteration 0 / 200: loss 85.880480
# iteration 100 / 200: loss 19.298938
# iteration 199 / 200: loss 10.407393
#
# ---------- 1.0e-07 5.0e+05 ----------
# iteration 0 / 200: loss 770.435830
# iteration 100 / 200: loss 8.999968
# iteration 199 / 200: loss 8.999965
#
# ---------- 1.0e-07 5.0e+06 ----------
# iteration 0 / 200: loss 7599.113917
# iteration 100 / 200: loss 9.000000
# iteration 199 / 200: loss 9.000001
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.094306 val accuracy: 0.077000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.101612 val accuracy: 0.101000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.079265 val accuracy: 0.083000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.109653 val accuracy: 0.118000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.109265 val accuracy: 0.113000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.407653 val accuracy: 0.405000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.134551 val accuracy: 0.136000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.400449 val accuracy: 0.388000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.308612 val accuracy: 0.325000
# best validation accuracy achieved: 0.405000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.416

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, min(examples_per_class,len(idxs)), replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
# 전혀 엉뚱하게 틀린 사진도 많지만,
#
# car 카테고리에 truck 사진이 많다거나, 초원배경이 흔한 bird, deer, horse 끼리 뒤바뀐다거나 하는식으로
#
# 비슷하게 생긴것들을 헷갈려하는 경우가 있는듯 함.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from math import ceil
from random import choice,uniform,randint
from cs231n import optim

#하이퍼파라미터 자동 random 서치
def search_hyperparameters(update_rule=None, num_search=80,
                           range_reg=[-5,5], range_lr=[-6,-2],
                           range_epochs=[1,1], print_every=300):
  best_solver = None

  for t_search in range(num_search):
    if update_rule is None:
      current_update_rule = choice([attr for attr in dir(optim) if callable(getattr(optim, attr))])
    else:
      current_update_rule = update_rule
    reg = 10**uniform(*range_reg)
    lr = 10**uniform(*range_lr)
    num_epochs = randint(*range_epochs)
    print(f"SEARCH {t_search+1} : update_rule={current_update_rule}, reg={reg:.3e}, \
lr={lr:.3e}, num_epochs={num_epochs}\n")

    net = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=reg)
    solver = Solver(net, data,
                    update_rule=current_update_rule,
                    optim_config={"learning_rate":lr},
                    num_epochs=num_epochs,
                    print_every=print_every)
    solver.train()

    if best_solver is None or best_solver.best_val_acc < solver.best_val_acc:
      best_net = net
      best_solver = solver
    print("\n************************************************************\n")

  print(f"The best model's validation accuracy is {best_solver.best_val_acc} with the following hyperparameters:")
  print(f"update_rule={best_solver.update_rule.__name__}, reg={best_net.reg:.3e}, \
lr={best_solver.optim_config['learning_rate']:.3e}, num_epochs={best_solver.num_epochs}")

  return best_solver, best_net

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# %%
# Coarse Stage
best_solver, best_net = search_hyperparameters()
# Out:
# SEARCH 1 : update_rule=adam, reg=4.129e-04, lr=1.169e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302623
# (Epoch 0 / 1) train acc: 0.208000; val_acc: 0.206000
# (Iteration 301 / 490) loss: 1.584213
# (Epoch 1 / 1) train acc: 0.464000; val_acc: 0.452000
#
# ************************************************************
#
# SEARCH 2 : update_rule=sgd, reg=3.674e+03, lr=3.939e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 152.821435
# (Epoch 0 / 1) train acc: 0.106000; val_acc: 0.099000
# (Iteration 301 / 490) loss: 2.302580
# (Epoch 1 / 1) train acc: 0.086000; val_acc: 0.079000
#
# ************************************************************
#
# SEARCH 3 : update_rule=sgd_momentum, reg=2.159e+02, lr=1.933e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 11.102859
# (Epoch 0 / 1) train acc: 0.106000; val_acc: 0.114000
# (Iteration 301 / 490) loss: 3.004603
# (Epoch 1 / 1) train acc: 0.114000; val_acc: 0.103000
#
# ************************************************************
#
# SEARCH 4 : update_rule=rmsprop, reg=4.169e-02, lr=6.915e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.304313
# (Epoch 0 / 1) train acc: 0.200000; val_acc: 0.183000
# (Iteration 301 / 490) loss: 1.871961
# (Epoch 1 / 1) train acc: 0.409000; val_acc: 0.385000
#
# ************************************************************
#
# SEARCH 5 : update_rule=sgd_momentum, reg=1.108e+02, lr=1.720e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 6.842472
# (Epoch 0 / 1) train acc: 0.103000; val_acc: 0.101000
# (Iteration 301 / 490) loss: 2.302595
# (Epoch 1 / 1) train acc: 0.106000; val_acc: 0.102000
#
# ************************************************************
#
# SEARCH 6 : update_rule=rmsprop, reg=1.116e-02, lr=1.782e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303030
# (Epoch 0 / 1) train acc: 0.125000; val_acc: 0.131000
# (Iteration 301 / 490) loss: 2.301589
# (Epoch 1 / 1) train acc: 0.375000; val_acc: 0.402000
#
# ************************************************************
#
# SEARCH 7 : update_rule=sgd, reg=4.840e+03, lr=5.131e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 200.466070
# (Epoch 0 / 1) train acc: 0.097000; val_acc: 0.121000
# (Iteration 301 / 490) loss: 2.302583
# (Epoch 1 / 1) train acc: 0.110000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 8 : update_rule=sgd_momentum, reg=1.242e-04, lr=6.672e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302586
# (Epoch 0 / 1) train acc: 0.101000; val_acc: 0.101000
# (Iteration 301 / 490) loss: 2.302362
# (Epoch 1 / 1) train acc: 0.202000; val_acc: 0.200000
#
# ************************************************************
#
# SEARCH 9 : update_rule=rmsprop, reg=5.846e+00, lr=1.597e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.541028
# (Epoch 0 / 1) train acc: 0.101000; val_acc: 0.074000
# (Iteration 301 / 490) loss: 2.382294
# (Epoch 1 / 1) train acc: 0.090000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 10 : update_rule=adam, reg=5.722e-03, lr=4.381e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302846
# (Epoch 0 / 1) train acc: 0.094000; val_acc: 0.100000
# (Iteration 301 / 490) loss: 2.297961
# (Epoch 1 / 1) train acc: 0.359000; val_acc: 0.355000
#
# ************************************************************
#
# SEARCH 11 : update_rule=sgd, reg=5.785e+02, lr=2.252e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 25.831691
# (Epoch 0 / 1) train acc: 0.096000; val_acc: 0.085000
# (Iteration 301 / 490) loss: 2.302574
# (Epoch 1 / 1) train acc: 0.113000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 12 : update_rule=rmsprop, reg=9.336e+03, lr=1.025e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 386.516347
# (Epoch 0 / 1) train acc: 0.106000; val_acc: 0.108000
# (Iteration 301 / 490) loss: 2.449007
# (Epoch 1 / 1) train acc: 0.089000; val_acc: 0.098000
#
# ************************************************************
#
# SEARCH 13 : update_rule=adam, reg=1.571e+00, lr=4.229e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.366840
# (Epoch 0 / 1) train acc: 0.093000; val_acc: 0.122000
# (Iteration 301 / 490) loss: 2.302553
# (Epoch 1 / 1) train acc: 0.105000; val_acc: 0.119000
#
# ************************************************************
#
# SEARCH 14 : update_rule=rmsprop, reg=1.106e-03, lr=1.510e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302653
# (Epoch 0 / 1) train acc: 0.234000; val_acc: 0.222000
# (Iteration 301 / 490) loss: 2.185913
# (Epoch 1 / 1) train acc: 0.300000; val_acc: 0.307000
#
# ************************************************************
#
# SEARCH 15 : update_rule=sgd, reg=5.794e-02, lr=3.753e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.304968
# (Epoch 0 / 1) train acc: 0.099000; val_acc: 0.075000
# (Iteration 301 / 490) loss: 2.304939
# (Epoch 1 / 1) train acc: 0.136000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 16 : update_rule=rmsprop, reg=9.964e-04, lr=3.087e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302639
# (Epoch 0 / 1) train acc: 0.104000; val_acc: 0.105000
# (Iteration 301 / 490) loss: 1.497023
# (Epoch 1 / 1) train acc: 0.570000; val_acc: 0.542000
#
# ************************************************************
#
# SEARCH 17 : update_rule=adam, reg=3.958e+01, lr=9.263e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 3.918640
# (Epoch 0 / 1) train acc: 0.093000; val_acc: 0.109000
# (Iteration 301 / 490) loss: 2.324336
# (Epoch 1 / 1) train acc: 0.099000; val_acc: 0.098000
#
# ************************************************************
#
# SEARCH 18 : update_rule=sgd_momentum, reg=4.606e+03, lr=3.115e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 191.002479
# (Epoch 0 / 1) train acc: 0.102000; val_acc: 0.106000
# (Iteration 301 / 490) loss: nan
# (Epoch 1 / 1) train acc: 0.091000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 19 : update_rule=adam, reg=5.915e-01, lr=1.119e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.326841
# (Epoch 0 / 1) train acc: 0.102000; val_acc: 0.096000
# (Iteration 301 / 490) loss: 2.302683
# (Epoch 1 / 1) train acc: 0.095000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 20 : update_rule=sgd, reg=4.278e-05, lr=1.186e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302555
# (Epoch 0 / 1) train acc: 0.097000; val_acc: 0.086000
# (Iteration 301 / 490) loss: 2.302597
# (Epoch 1 / 1) train acc: 0.078000; val_acc: 0.086000
#
# ************************************************************
#
# SEARCH 21 : update_rule=sgd, reg=7.501e-05, lr=3.466e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302593
# (Epoch 0 / 1) train acc: 0.091000; val_acc: 0.098000
# (Iteration 301 / 490) loss: 2.302541
# (Epoch 1 / 1) train acc: 0.091000; val_acc: 0.098000
#
# ************************************************************
#
# SEARCH 22 : update_rule=rmsprop, reg=2.961e-02, lr=3.181e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303786
# (Epoch 0 / 1) train acc: 0.103000; val_acc: 0.125000
# (Iteration 301 / 490) loss: 1.724547
# (Epoch 1 / 1) train acc: 0.509000; val_acc: 0.505000
#
# ************************************************************
#
# SEARCH 23 : update_rule=rmsprop, reg=1.791e-04, lr=6.013e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302582
# (Epoch 0 / 1) train acc: 0.168000; val_acc: 0.167000
# (Iteration 301 / 490) loss: 2.284891
# (Epoch 1 / 1) train acc: 0.355000; val_acc: 0.342000
#
# ************************************************************
#
# SEARCH 24 : update_rule=adam, reg=7.914e-03, lr=3.216e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302935
# (Epoch 0 / 1) train acc: 0.110000; val_acc: 0.091000
# (Iteration 301 / 490) loss: 2.300454
# (Epoch 1 / 1) train acc: 0.334000; val_acc: 0.369000
#
# ************************************************************
#
# SEARCH 25 : update_rule=sgd, reg=6.699e+04, lr=2.638e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2756.433367
# (Epoch 0 / 1) train acc: 0.114000; val_acc: 0.133000
# (Iteration 301 / 490) loss: nan
# (Epoch 1 / 1) train acc: 0.102000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 26 : update_rule=sgd, reg=5.019e-02, lr=1.157e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.304643
# (Epoch 0 / 1) train acc: 0.092000; val_acc: 0.084000
# (Iteration 301 / 490) loss: 2.304629
# (Epoch 1 / 1) train acc: 0.099000; val_acc: 0.102000
#
# ************************************************************
#
# SEARCH 27 : update_rule=sgd_momentum, reg=1.780e+03, lr=2.980e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 75.498336
# (Epoch 0 / 1) train acc: 0.078000; val_acc: 0.091000
# (Iteration 301 / 490) loss: 2.302588
# (Epoch 1 / 1) train acc: 0.096000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 28 : update_rule=sgd_momentum, reg=7.298e-05, lr=4.250e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302594
# (Epoch 0 / 1) train acc: 0.100000; val_acc: 0.103000
# (Iteration 301 / 490) loss: 2.301965
# (Epoch 1 / 1) train acc: 0.106000; val_acc: 0.120000
#
# ************************************************************
#
# SEARCH 29 : update_rule=rmsprop, reg=1.276e-03, lr=3.093e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302626
# (Epoch 0 / 1) train acc: 0.170000; val_acc: 0.170000
# (Iteration 301 / 490) loss: 1.639718
# (Epoch 1 / 1) train acc: 0.524000; val_acc: 0.523000
#
# ************************************************************
#
# SEARCH 30 : update_rule=adam, reg=3.863e+00, lr=1.850e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.460615
# (Epoch 0 / 1) train acc: 0.093000; val_acc: 0.099000
# (Iteration 301 / 490) loss: 2.302751
# (Epoch 1 / 1) train acc: 0.105000; val_acc: 0.113000
#
# ************************************************************
#
# SEARCH 31 : update_rule=sgd, reg=5.280e+00, lr=2.923e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.519883
# (Epoch 0 / 1) train acc: 0.088000; val_acc: 0.115000
# (Iteration 301 / 490) loss: 2.388592
# (Epoch 1 / 1) train acc: 0.107000; val_acc: 0.119000
#
# ************************************************************
#
# SEARCH 32 : update_rule=sgd, reg=1.023e+02, lr=3.934e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 6.488934
# (Epoch 0 / 1) train acc: 0.108000; val_acc: 0.110000
# (Iteration 301 / 490) loss: 2.674808
# (Epoch 1 / 1) train acc: 0.102000; val_acc: 0.112000
#
# ************************************************************
#
# SEARCH 33 : update_rule=sgd_momentum, reg=2.706e+00, lr=9.838e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.412852
# (Epoch 0 / 1) train acc: 0.104000; val_acc: 0.088000
# (Iteration 301 / 490) loss: 2.325139
# (Epoch 1 / 1) train acc: 0.095000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 34 : update_rule=sgd_momentum, reg=3.351e+00, lr=1.820e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.439897
# (Epoch 0 / 1) train acc: 0.087000; val_acc: 0.068000
# (Iteration 301 / 490) loss: 2.303690
# (Epoch 1 / 1) train acc: 0.103000; val_acc: 0.102000
#
# ************************************************************
#
# SEARCH 35 : update_rule=adam, reg=1.255e-02, lr=1.091e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303118
# (Epoch 0 / 1) train acc: 0.192000; val_acc: 0.187000
# (Iteration 301 / 490) loss: 1.649037
# (Epoch 1 / 1) train acc: 0.446000; val_acc: 0.437000
#
# ************************************************************
#
# SEARCH 36 : update_rule=rmsprop, reg=3.052e+03, lr=2.265e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 128.416301
# (Epoch 0 / 1) train acc: 0.100000; val_acc: 0.091000
# (Iteration 301 / 490) loss: 28.524199
# (Epoch 1 / 1) train acc: 0.102000; val_acc: 0.105000
#
# ************************************************************
#
# SEARCH 37 : update_rule=sgd_momentum, reg=2.518e+04, lr=1.239e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 1040.843359
# (Epoch 0 / 1) train acc: 0.107000; val_acc: 0.088000
# (Iteration 301 / 490) loss: 2.302584
# (Epoch 1 / 1) train acc: 0.111000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 38 : update_rule=adam, reg=1.219e-03, lr=4.325e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302678
# (Epoch 0 / 1) train acc: 0.147000; val_acc: 0.121000
# (Iteration 301 / 490) loss: 1.223229
# (Epoch 1 / 1) train acc: 0.587000; val_acc: 0.531000
#
# ************************************************************
#
# SEARCH 39 : update_rule=adam, reg=4.221e+01, lr=1.573e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 4.022299
# (Epoch 0 / 1) train acc: 0.119000; val_acc: 0.125000
# (Iteration 301 / 490) loss: 2.302489
# (Epoch 1 / 1) train acc: 0.106000; val_acc: 0.079000
#
# ************************************************************
#
# SEARCH 40 : update_rule=rmsprop, reg=1.023e+03, lr=1.936e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 44.396490
# (Epoch 0 / 1) train acc: 0.096000; val_acc: 0.103000
# (Iteration 301 / 490) loss: 2.303613
# (Epoch 1 / 1) train acc: 0.086000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 41 : update_rule=adam, reg=7.706e+00, lr=1.564e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.618805
# (Epoch 0 / 1) train acc: 0.083000; val_acc: 0.099000
# (Iteration 301 / 490) loss: 2.301356
# (Epoch 1 / 1) train acc: 0.107000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 42 : update_rule=rmsprop, reg=7.826e-02, lr=4.226e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.305797
# (Epoch 0 / 1) train acc: 0.200000; val_acc: 0.189000
# (Iteration 301 / 490) loss: 2.107781
# (Epoch 1 / 1) train acc: 0.265000; val_acc: 0.301000
#
# ************************************************************
#
# SEARCH 43 : update_rule=sgd, reg=2.462e+04, lr=1.818e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 1013.184151
# (Epoch 0 / 1) train acc: 0.088000; val_acc: 0.086000
# (Iteration 301 / 490) loss: nan
# (Epoch 1 / 1) train acc: 0.110000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 44 : update_rule=adam, reg=4.939e+01, lr=6.294e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 4.330294
# (Epoch 0 / 1) train acc: 0.090000; val_acc: 0.090000
# (Iteration 301 / 490) loss: 2.412465
# (Epoch 1 / 1) train acc: 0.099000; val_acc: 0.079000
#
# ************************************************************
#
# SEARCH 45 : update_rule=adam, reg=3.638e+02, lr=3.770e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 17.208924
# (Epoch 0 / 1) train acc: 0.087000; val_acc: 0.101000
# (Iteration 301 / 490) loss: 2.302026
# (Epoch 1 / 1) train acc: 0.104000; val_acc: 0.079000
#
# ************************************************************
#
# SEARCH 46 : update_rule=adam, reg=2.803e-02, lr=5.093e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303764
# (Epoch 0 / 1) train acc: 0.186000; val_acc: 0.164000
# (Iteration 301 / 490) loss: 1.979932
# (Epoch 1 / 1) train acc: 0.379000; val_acc: 0.358000
#
# ************************************************************
#
# SEARCH 47 : update_rule=adam, reg=2.819e+04, lr=8.418e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 1161.890502
# (Epoch 0 / 1) train acc: 0.094000; val_acc: 0.104000
# (Iteration 301 / 490) loss: 2.302428
# (Epoch 1 / 1) train acc: 0.106000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 48 : update_rule=sgd_momentum, reg=2.318e-03, lr=7.370e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302706
# (Epoch 0 / 1) train acc: 0.097000; val_acc: 0.086000
# (Iteration 301 / 490) loss: 2.302227
# (Epoch 1 / 1) train acc: 0.179000; val_acc: 0.158000
#
# ************************************************************
#
# SEARCH 49 : update_rule=adam, reg=3.584e-02, lr=1.623e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.304028
# (Epoch 0 / 1) train acc: 0.218000; val_acc: 0.199000
# (Iteration 301 / 490) loss: 1.852123
# (Epoch 1 / 1) train acc: 0.444000; val_acc: 0.427000
#
# ************************************************************
#
# SEARCH 50 : update_rule=rmsprop, reg=5.061e-01, lr=4.748e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.323231
# (Epoch 0 / 1) train acc: 0.175000; val_acc: 0.214000
# (Iteration 301 / 490) loss: 2.302262
# (Epoch 1 / 1) train acc: 0.152000; val_acc: 0.156000
#
# ************************************************************
#
# SEARCH 51 : update_rule=adam, reg=6.586e-04, lr=4.238e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302611
# (Epoch 0 / 1) train acc: 0.145000; val_acc: 0.139000
# (Iteration 301 / 490) loss: 2.297719
# (Epoch 1 / 1) train acc: 0.340000; val_acc: 0.340000
#
# ************************************************************
#
# SEARCH 52 : update_rule=rmsprop, reg=3.615e-04, lr=3.360e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302581
# (Epoch 0 / 1) train acc: 0.150000; val_acc: 0.155000
# (Iteration 301 / 490) loss: 2.296729
# (Epoch 1 / 1) train acc: 0.342000; val_acc: 0.341000
#
# ************************************************************
#
# SEARCH 53 : update_rule=rmsprop, reg=2.895e+03, lr=1.800e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 120.563667
# (Epoch 0 / 1) train acc: 0.088000; val_acc: 0.085000
# (Iteration 301 / 490) loss: 36.487022
# (Epoch 1 / 1) train acc: 0.105000; val_acc: 0.108000
#
# ************************************************************
#
# SEARCH 54 : update_rule=rmsprop, reg=1.635e+01, lr=2.371e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.972150
# (Epoch 0 / 1) train acc: 0.080000; val_acc: 0.098000
# (Iteration 301 / 490) loss: 2.302687
# (Epoch 1 / 1) train acc: 0.103000; val_acc: 0.105000
#
# ************************************************************
#
# SEARCH 55 : update_rule=sgd_momentum, reg=6.825e-04, lr=2.292e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302594
# (Epoch 0 / 1) train acc: 0.121000; val_acc: 0.100000
# (Iteration 301 / 490) loss: 2.295804
# (Epoch 1 / 1) train acc: 0.226000; val_acc: 0.241000
#
# ************************************************************
#
# SEARCH 56 : update_rule=sgd_momentum, reg=5.545e-02, lr=1.941e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.304848
# (Epoch 0 / 1) train acc: 0.107000; val_acc: 0.114000
# (Iteration 301 / 490) loss: 2.300863
# (Epoch 1 / 1) train acc: 0.254000; val_acc: 0.257000
#
# ************************************************************
#
# SEARCH 57 : update_rule=sgd_momentum, reg=1.044e+03, lr=7.497e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 45.038138
# (Epoch 0 / 1) train acc: 0.108000; val_acc: 0.107000
# (Iteration 301 / 490) loss: 2.302464
# (Epoch 1 / 1) train acc: 0.081000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 58 : update_rule=sgd_momentum, reg=8.078e-05, lr=1.530e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302565
# (Epoch 0 / 1) train acc: 0.101000; val_acc: 0.132000
# (Iteration 301 / 490) loss: 2.302596
# (Epoch 1 / 1) train acc: 0.108000; val_acc: 0.132000
#
# ************************************************************
#
# SEARCH 59 : update_rule=sgd, reg=2.986e+01, lr=2.146e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 3.529006
# (Epoch 0 / 1) train acc: 0.099000; val_acc: 0.105000
# (Iteration 301 / 490) loss: 3.482776
# (Epoch 1 / 1) train acc: 0.121000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 60 : update_rule=adam, reg=2.112e+02, lr=5.006e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 10.882257
# (Epoch 0 / 1) train acc: 0.090000; val_acc: 0.104000
# (Iteration 301 / 490) loss: 2.301991
# (Epoch 1 / 1) train acc: 0.104000; val_acc: 0.087000
#
# ************************************************************
#
# SEARCH 61 : update_rule=adam, reg=3.540e-05, lr=1.063e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302604
# (Epoch 0 / 1) train acc: 0.193000; val_acc: 0.205000
# (Iteration 301 / 490) loss: 1.648289
# (Epoch 1 / 1) train acc: 0.446000; val_acc: 0.437000
#
# ************************************************************
#
# SEARCH 62 : update_rule=sgd, reg=1.179e-05, lr=6.175e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302584
# (Epoch 0 / 1) train acc: 0.118000; val_acc: 0.127000
# (Iteration 301 / 490) loss: 2.302256
# (Epoch 1 / 1) train acc: 0.151000; val_acc: 0.159000
#
# ************************************************************
#
# SEARCH 63 : update_rule=sgd_momentum, reg=4.683e+04, lr=7.028e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 1928.128552
# (Epoch 0 / 1) train acc: 0.121000; val_acc: 0.099000
# (Iteration 301 / 490) loss: 2.302587
# (Epoch 1 / 1) train acc: 0.098000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 64 : update_rule=rmsprop, reg=5.623e+04, lr=1.384e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2320.205112
# (Epoch 0 / 1) train acc: 0.093000; val_acc: 0.114000
# (Iteration 301 / 490) loss: 2.350977
# (Epoch 1 / 1) train acc: 0.082000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 65 : update_rule=sgd, reg=2.997e-02, lr=2.292e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303796
# (Epoch 0 / 1) train acc: 0.101000; val_acc: 0.082000
# (Iteration 301 / 490) loss: 2.303831
# (Epoch 1 / 1) train acc: 0.084000; val_acc: 0.089000
#
# ************************************************************
#
# SEARCH 66 : update_rule=rmsprop, reg=1.208e-02, lr=4.622e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303090
# (Epoch 0 / 1) train acc: 0.142000; val_acc: 0.125000
# (Iteration 301 / 490) loss: 1.616665
# (Epoch 1 / 1) train acc: 0.516000; val_acc: 0.500000
#
# ************************************************************
#
# SEARCH 67 : update_rule=sgd_momentum, reg=8.766e-05, lr=5.905e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302597
# (Epoch 0 / 1) train acc: 0.081000; val_acc: 0.103000
# (Iteration 301 / 490) loss: 2.302535
# (Epoch 1 / 1) train acc: 0.095000; val_acc: 0.077000
#
# ************************************************************
#
# SEARCH 68 : update_rule=sgd_momentum, reg=1.830e-03, lr=4.450e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302638
# (Epoch 0 / 1) train acc: 0.102000; val_acc: 0.136000
# (Iteration 301 / 490) loss: 2.182154
# (Epoch 1 / 1) train acc: 0.384000; val_acc: 0.356000
#
# ************************************************************
#
# SEARCH 69 : update_rule=sgd, reg=1.655e-02, lr=3.413e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.303227
# (Epoch 0 / 1) train acc: 0.117000; val_acc: 0.112000
# (Iteration 301 / 490) loss: 2.303178
# (Epoch 1 / 1) train acc: 0.128000; val_acc: 0.117000
#
# ************************************************************
#
# SEARCH 70 : update_rule=adam, reg=7.144e+00, lr=1.121e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.594154
# (Epoch 0 / 1) train acc: 0.107000; val_acc: 0.097000
# (Iteration 301 / 490) loss: 2.302515
# (Epoch 1 / 1) train acc: 0.091000; val_acc: 0.119000
#
# ************************************************************
#
# SEARCH 71 : update_rule=sgd_momentum, reg=2.959e-03, lr=2.424e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302690
# (Epoch 0 / 1) train acc: 0.110000; val_acc: 0.107000
# (Iteration 301 / 490) loss: 2.302684
# (Epoch 1 / 1) train acc: 0.117000; val_acc: 0.106000
#
# ************************************************************
#
# SEARCH 72 : update_rule=sgd, reg=1.105e+01, lr=1.168e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.754436
# (Epoch 0 / 1) train acc: 0.104000; val_acc: 0.114000
# (Iteration 301 / 490) loss: 2.302751
# (Epoch 1 / 1) train acc: 0.100000; val_acc: 0.113000
#
# ************************************************************
#
# SEARCH 73 : update_rule=sgd_momentum, reg=4.722e-04, lr=2.355e-05, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302592
# (Epoch 0 / 1) train acc: 0.102000; val_acc: 0.107000
# (Iteration 301 / 490) loss: 2.302591
# (Epoch 1 / 1) train acc: 0.106000; val_acc: 0.112000
#
# ************************************************************
#
# SEARCH 74 : update_rule=sgd_momentum, reg=7.077e+04, lr=2.025e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 2906.473115
# (Epoch 0 / 1) train acc: 0.092000; val_acc: 0.110000
# (Iteration 301 / 490) loss: 2.302584
# (Epoch 1 / 1) train acc: 0.094000; val_acc: 0.107000
#
# ************************************************************
#
# SEARCH 75 : update_rule=adam, reg=1.261e-03, lr=1.337e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302633
# (Epoch 0 / 1) train acc: 0.209000; val_acc: 0.238000
# (Iteration 301 / 490) loss: 1.594961
# (Epoch 1 / 1) train acc: 0.452000; val_acc: 0.464000
#
# ************************************************************
#
# SEARCH 76 : update_rule=sgd, reg=1.981e-01, lr=1.149e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.310634
# (Epoch 0 / 1) train acc: 0.108000; val_acc: 0.088000
# (Iteration 301 / 490) loss: 2.309560
# (Epoch 1 / 1) train acc: 0.102000; val_acc: 0.135000
#
# ************************************************************
#
# SEARCH 77 : update_rule=sgd_momentum, reg=7.410e-04, lr=1.305e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302662
# (Epoch 0 / 1) train acc: 0.096000; val_acc: 0.110000
# (Iteration 301 / 490) loss: 2.301858
# (Epoch 1 / 1) train acc: 0.184000; val_acc: 0.208000
#
# ************************************************************
#
# SEARCH 78 : update_rule=sgd, reg=1.418e-01, lr=8.018e-04, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.308394
# (Epoch 0 / 1) train acc: 0.107000; val_acc: 0.070000
# (Iteration 301 / 490) loss: 2.308002
# (Epoch 1 / 1) train acc: 0.188000; val_acc: 0.161000
#
# ************************************************************
#
# SEARCH 79 : update_rule=rmsprop, reg=9.241e+03, lr=5.401e-06, num_epochs=1
#
# (Iteration 1 / 490) loss: 376.813341
# (Epoch 0 / 1) train acc: 0.095000; val_acc: 0.066000
# (Iteration 301 / 490) loss: 9.437136
# (Epoch 1 / 1) train acc: 0.088000; val_acc: 0.078000
#
# ************************************************************
#
# SEARCH 80 : update_rule=adam, reg=9.370e-05, lr=1.927e-03, num_epochs=1
#
# (Iteration 1 / 490) loss: 2.302580
# (Epoch 0 / 1) train acc: 0.213000; val_acc: 0.165000
# (Iteration 301 / 490) loss: 1.082107
# (Epoch 1 / 1) train acc: 0.592000; val_acc: 0.532000
#
# ************************************************************
#
# The best model's validation accuracy is 0.542 with the following hyperparameters:
# update_rule=rmsprop, reg=9.964e-04, lr=3.087e-03, num_epochs=1

# %%
# 위의 Coarse Stage 결과를 기준으로, 범위를 재설정하고, epoch수를 늘림.

# Fine Stage
best_solver, best_net = search_hyperparameters(num_search=30,
                                                 update_rule="rmsprop",
                                                 range_reg=[-4,-2],
                                                 range_lr=[-3.5,-2],
                                                 range_epochs=[5,10],
                                                 print_every=1000)
# Out:
# SEARCH 1 : update_rule=rmsprop, reg=4.945e-04, lr=4.730e-04, num_epochs=8
#
# (Iteration 1 / 3920) loss: 2.302588
# (Epoch 0 / 8) train acc: 0.155000; val_acc: 0.175000
# (Epoch 1 / 8) train acc: 0.554000; val_acc: 0.526000
# (Epoch 2 / 8) train acc: 0.595000; val_acc: 0.547000
# (Iteration 1001 / 3920) loss: 1.246264
# (Epoch 3 / 8) train acc: 0.587000; val_acc: 0.576000
# (Epoch 4 / 8) train acc: 0.607000; val_acc: 0.585000
# (Iteration 2001 / 3920) loss: 1.202509
# (Epoch 5 / 8) train acc: 0.648000; val_acc: 0.600000
# (Epoch 6 / 8) train acc: 0.675000; val_acc: 0.600000
# (Iteration 3001 / 3920) loss: 0.993182
# (Epoch 7 / 8) train acc: 0.674000; val_acc: 0.586000
# (Epoch 8 / 8) train acc: 0.690000; val_acc: 0.600000
#
# ************************************************************
#
# SEARCH 2 : update_rule=rmsprop, reg=9.738e-04, lr=3.593e-04, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302610
# (Epoch 0 / 5) train acc: 0.134000; val_acc: 0.146000
# (Epoch 1 / 5) train acc: 0.541000; val_acc: 0.527000
# (Epoch 2 / 5) train acc: 0.552000; val_acc: 0.544000
# (Iteration 1001 / 2450) loss: 1.181696
# (Epoch 3 / 5) train acc: 0.556000; val_acc: 0.545000
# (Epoch 4 / 5) train acc: 0.593000; val_acc: 0.577000
# (Iteration 2001 / 2450) loss: 1.215840
# (Epoch 5 / 5) train acc: 0.642000; val_acc: 0.579000
#
# ************************************************************
#
# SEARCH 3 : update_rule=rmsprop, reg=2.637e-04, lr=3.072e-03, num_epochs=9
#
# (Iteration 1 / 4410) loss: 2.302609
# (Epoch 0 / 9) train acc: 0.110000; val_acc: 0.116000
# (Epoch 1 / 9) train acc: 0.614000; val_acc: 0.548000
# (Epoch 2 / 9) train acc: 0.652000; val_acc: 0.551000
# (Iteration 1001 / 4410) loss: 1.116690
# (Epoch 3 / 9) train acc: 0.683000; val_acc: 0.562000
# (Epoch 4 / 9) train acc: 0.723000; val_acc: 0.582000
# (Iteration 2001 / 4410) loss: 0.742594
# (Epoch 5 / 9) train acc: 0.702000; val_acc: 0.572000
# (Epoch 6 / 9) train acc: 0.765000; val_acc: 0.572000
# (Iteration 3001 / 4410) loss: 0.731054
# (Epoch 7 / 9) train acc: 0.762000; val_acc: 0.557000
# (Epoch 8 / 9) train acc: 0.770000; val_acc: 0.545000
# (Iteration 4001 / 4410) loss: 0.843723
# (Epoch 9 / 9) train acc: 0.752000; val_acc: 0.559000
#
# ************************************************************
#
# SEARCH 4 : update_rule=rmsprop, reg=1.178e-03, lr=8.428e-03, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302628
# (Epoch 0 / 5) train acc: 0.103000; val_acc: 0.105000
# (Epoch 1 / 5) train acc: 0.521000; val_acc: 0.473000
# (Epoch 2 / 5) train acc: 0.589000; val_acc: 0.546000
# (Iteration 1001 / 2450) loss: 1.375485
# (Epoch 3 / 5) train acc: 0.587000; val_acc: 0.533000
# (Epoch 4 / 5) train acc: 0.601000; val_acc: 0.519000
# (Iteration 2001 / 2450) loss: 1.378321
# (Epoch 5 / 5) train acc: 0.609000; val_acc: 0.537000
#
# ************************************************************
#
# SEARCH 5 : update_rule=rmsprop, reg=1.458e-03, lr=4.386e-04, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302654
# (Epoch 0 / 6) train acc: 0.104000; val_acc: 0.118000
# (Epoch 1 / 6) train acc: 0.519000; val_acc: 0.537000
# (Epoch 2 / 6) train acc: 0.570000; val_acc: 0.541000
# (Iteration 1001 / 2940) loss: 1.302464
# (Epoch 3 / 6) train acc: 0.596000; val_acc: 0.558000
# (Epoch 4 / 6) train acc: 0.612000; val_acc: 0.573000
# (Iteration 2001 / 2940) loss: 1.211641
# (Epoch 5 / 6) train acc: 0.662000; val_acc: 0.571000
# (Epoch 6 / 6) train acc: 0.655000; val_acc: 0.585000
#
# ************************************************************
#
# SEARCH 6 : update_rule=rmsprop, reg=1.891e-04, lr=1.014e-03, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302648
# (Epoch 0 / 6) train acc: 0.103000; val_acc: 0.113000
# (Epoch 1 / 6) train acc: 0.565000; val_acc: 0.549000
# (Epoch 2 / 6) train acc: 0.638000; val_acc: 0.582000
# (Iteration 1001 / 2940) loss: 1.136773
# (Epoch 3 / 6) train acc: 0.660000; val_acc: 0.580000
# (Epoch 4 / 6) train acc: 0.684000; val_acc: 0.601000
# (Iteration 2001 / 2940) loss: 0.840142
# (Epoch 5 / 6) train acc: 0.724000; val_acc: 0.600000
# (Epoch 6 / 6) train acc: 0.733000; val_acc: 0.588000
#
# ************************************************************
#
# SEARCH 7 : update_rule=rmsprop, reg=1.103e-04, lr=6.029e-03, num_epochs=10
#
# (Iteration 1 / 4900) loss: 2.302561
# (Epoch 0 / 10) train acc: 0.094000; val_acc: 0.107000
# (Epoch 1 / 10) train acc: 0.612000; val_acc: 0.532000
# (Epoch 2 / 10) train acc: 0.623000; val_acc: 0.541000
# (Iteration 1001 / 4900) loss: 1.302371
# (Epoch 3 / 10) train acc: 0.630000; val_acc: 0.523000
# (Epoch 4 / 10) train acc: 0.673000; val_acc: 0.529000
# (Iteration 2001 / 4900) loss: 1.183212
# (Epoch 5 / 10) train acc: 0.688000; val_acc: 0.534000
# (Epoch 6 / 10) train acc: 0.741000; val_acc: 0.538000
# (Iteration 3001 / 4900) loss: 0.862304
# (Epoch 7 / 10) train acc: 0.727000; val_acc: 0.535000
# (Epoch 8 / 10) train acc: 0.724000; val_acc: 0.542000
# (Iteration 4001 / 4900) loss: 1.007683
# (Epoch 9 / 10) train acc: 0.755000; val_acc: 0.545000
# (Epoch 10 / 10) train acc: 0.740000; val_acc: 0.532000
#
# ************************************************************
#
# SEARCH 8 : update_rule=rmsprop, reg=7.372e-03, lr=4.905e-04, num_epochs=7
#
# (Iteration 1 / 3430) loss: 2.302894
# (Epoch 0 / 7) train acc: 0.117000; val_acc: 0.115000
# (Epoch 1 / 7) train acc: 0.534000; val_acc: 0.517000
# (Epoch 2 / 7) train acc: 0.551000; val_acc: 0.531000
# (Iteration 1001 / 3430) loss: 1.430875
# (Epoch 3 / 7) train acc: 0.554000; val_acc: 0.553000
# (Epoch 4 / 7) train acc: 0.573000; val_acc: 0.561000
# (Iteration 2001 / 3430) loss: 1.387960
# (Epoch 5 / 7) train acc: 0.568000; val_acc: 0.557000
# (Epoch 6 / 7) train acc: 0.575000; val_acc: 0.562000
# (Iteration 3001 / 3430) loss: 1.495860
# (Epoch 7 / 7) train acc: 0.616000; val_acc: 0.560000
#
# ************************************************************
#
# SEARCH 9 : update_rule=rmsprop, reg=9.557e-03, lr=6.753e-03, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302968
# (Epoch 0 / 6) train acc: 0.106000; val_acc: 0.076000
# (Epoch 1 / 6) train acc: 0.505000; val_acc: 0.488000
# (Epoch 2 / 6) train acc: 0.517000; val_acc: 0.506000
# (Iteration 1001 / 2940) loss: 1.666444
# (Epoch 3 / 6) train acc: 0.516000; val_acc: 0.505000
# (Epoch 4 / 6) train acc: 0.507000; val_acc: 0.511000
# (Iteration 2001 / 2940) loss: 1.527799
# (Epoch 5 / 6) train acc: 0.534000; val_acc: 0.513000
# (Epoch 6 / 6) train acc: 0.512000; val_acc: 0.504000
#
# ************************************************************
#
# SEARCH 10 : update_rule=rmsprop, reg=1.592e-03, lr=3.545e-03, num_epochs=8
#
# (Iteration 1 / 3920) loss: 2.302678
# (Epoch 0 / 8) train acc: 0.095000; val_acc: 0.110000
# (Epoch 1 / 8) train acc: 0.583000; val_acc: 0.533000
# (Epoch 2 / 8) train acc: 0.618000; val_acc: 0.566000
# (Iteration 1001 / 3920) loss: 1.119493
# (Epoch 3 / 8) train acc: 0.612000; val_acc: 0.548000
# (Epoch 4 / 8) train acc: 0.625000; val_acc: 0.569000
# (Iteration 2001 / 3920) loss: 1.311482
# (Epoch 5 / 8) train acc: 0.607000; val_acc: 0.546000
# (Epoch 6 / 8) train acc: 0.658000; val_acc: 0.562000
# (Iteration 3001 / 3920) loss: 1.128135
# (Epoch 7 / 8) train acc: 0.648000; val_acc: 0.571000
# (Epoch 8 / 8) train acc: 0.670000; val_acc: 0.558000
#
# ************************************************************
#
# SEARCH 11 : update_rule=rmsprop, reg=1.883e-03, lr=3.709e-03, num_epochs=9
#
# (Iteration 1 / 4410) loss: 2.302656
# (Epoch 0 / 9) train acc: 0.090000; val_acc: 0.111000
# (Epoch 1 / 9) train acc: 0.589000; val_acc: 0.529000
# (Epoch 2 / 9) train acc: 0.589000; val_acc: 0.569000
# (Iteration 1001 / 4410) loss: 1.171079
# (Epoch 3 / 9) train acc: 0.603000; val_acc: 0.550000
# (Epoch 4 / 9) train acc: 0.636000; val_acc: 0.548000
# (Iteration 2001 / 4410) loss: 1.224726
# (Epoch 5 / 9) train acc: 0.600000; val_acc: 0.558000
# (Epoch 6 / 9) train acc: 0.657000; val_acc: 0.574000
# (Iteration 3001 / 4410) loss: 1.172905
# (Epoch 7 / 9) train acc: 0.654000; val_acc: 0.562000
# (Epoch 8 / 9) train acc: 0.645000; val_acc: 0.541000
# (Iteration 4001 / 4410) loss: 1.474398
# (Epoch 9 / 9) train acc: 0.654000; val_acc: 0.581000
#
# ************************************************************
#
# SEARCH 12 : update_rule=rmsprop, reg=1.886e-04, lr=4.442e-04, num_epochs=10
#
# (Iteration 1 / 4900) loss: 2.302576
# (Epoch 0 / 10) train acc: 0.111000; val_acc: 0.109000
# (Epoch 1 / 10) train acc: 0.544000; val_acc: 0.528000
# (Epoch 2 / 10) train acc: 0.569000; val_acc: 0.540000
# (Iteration 1001 / 4900) loss: 1.282684
# (Epoch 3 / 10) train acc: 0.601000; val_acc: 0.557000
# (Epoch 4 / 10) train acc: 0.625000; val_acc: 0.569000
# (Iteration 2001 / 4900) loss: 1.037162
# (Epoch 5 / 10) train acc: 0.667000; val_acc: 0.583000
# (Epoch 6 / 10) train acc: 0.645000; val_acc: 0.593000
# (Iteration 3001 / 4900) loss: 0.937452
# (Epoch 7 / 10) train acc: 0.661000; val_acc: 0.612000
# (Epoch 8 / 10) train acc: 0.675000; val_acc: 0.612000
# (Iteration 4001 / 4900) loss: 0.824122
# (Epoch 9 / 10) train acc: 0.694000; val_acc: 0.620000
# (Epoch 10 / 10) train acc: 0.708000; val_acc: 0.625000
#
# ************************************************************
#
# SEARCH 13 : update_rule=rmsprop, reg=9.496e-04, lr=5.429e-03, num_epochs=10
#
# (Iteration 1 / 4900) loss: 2.302641
# (Epoch 0 / 10) train acc: 0.086000; val_acc: 0.111000
# (Epoch 1 / 10) train acc: 0.596000; val_acc: 0.528000
# (Epoch 2 / 10) train acc: 0.591000; val_acc: 0.550000
# (Iteration 1001 / 4900) loss: 1.193198
# (Epoch 3 / 10) train acc: 0.613000; val_acc: 0.560000
# (Epoch 4 / 10) train acc: 0.631000; val_acc: 0.568000
# (Iteration 2001 / 4900) loss: 1.324208
# (Epoch 5 / 10) train acc: 0.654000; val_acc: 0.575000
# (Epoch 6 / 10) train acc: 0.638000; val_acc: 0.557000
# (Iteration 3001 / 4900) loss: 1.362756
# (Epoch 7 / 10) train acc: 0.642000; val_acc: 0.539000
# (Epoch 8 / 10) train acc: 0.653000; val_acc: 0.554000
# (Iteration 4001 / 4900) loss: 1.308419
# (Epoch 9 / 10) train acc: 0.636000; val_acc: 0.559000
# (Epoch 10 / 10) train acc: 0.656000; val_acc: 0.560000
#
# ************************************************************
#
# SEARCH 14 : update_rule=rmsprop, reg=1.590e-04, lr=8.887e-04, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302618
# (Epoch 0 / 5) train acc: 0.139000; val_acc: 0.176000
# (Epoch 1 / 5) train acc: 0.583000; val_acc: 0.557000
# (Epoch 2 / 5) train acc: 0.617000; val_acc: 0.572000
# (Iteration 1001 / 2450) loss: 1.129286
# (Epoch 3 / 5) train acc: 0.636000; val_acc: 0.596000
# (Epoch 4 / 5) train acc: 0.698000; val_acc: 0.599000
# (Iteration 2001 / 2450) loss: 0.867935
# (Epoch 5 / 5) train acc: 0.706000; val_acc: 0.601000
#
# ************************************************************
#
# SEARCH 15 : update_rule=rmsprop, reg=1.204e-04, lr=1.402e-03, num_epochs=8
#
# (Iteration 1 / 3920) loss: 2.302578
# (Epoch 0 / 8) train acc: 0.098000; val_acc: 0.098000
# (Epoch 1 / 8) train acc: 0.585000; val_acc: 0.569000
# (Epoch 2 / 8) train acc: 0.615000; val_acc: 0.574000
# (Iteration 1001 / 3920) loss: 1.045460
# (Epoch 3 / 8) train acc: 0.686000; val_acc: 0.595000
# (Epoch 4 / 8) train acc: 0.708000; val_acc: 0.565000
# (Iteration 2001 / 3920) loss: 0.919722
# (Epoch 5 / 8) train acc: 0.732000; val_acc: 0.581000
# (Epoch 6 / 8) train acc: 0.763000; val_acc: 0.575000
# (Iteration 3001 / 3920) loss: 0.782998
# (Epoch 7 / 8) train acc: 0.760000; val_acc: 0.595000
# (Epoch 8 / 8) train acc: 0.778000; val_acc: 0.586000
#
# ************************************************************
#
# SEARCH 16 : update_rule=rmsprop, reg=8.547e-03, lr=4.415e-04, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302895
# (Epoch 0 / 6) train acc: 0.148000; val_acc: 0.161000
# (Epoch 1 / 6) train acc: 0.534000; val_acc: 0.519000
# (Epoch 2 / 6) train acc: 0.511000; val_acc: 0.526000
# (Iteration 1001 / 2940) loss: 1.550454
# (Epoch 3 / 6) train acc: 0.550000; val_acc: 0.536000
# (Epoch 4 / 6) train acc: 0.575000; val_acc: 0.533000
# (Iteration 2001 / 2940) loss: 1.456477
# (Epoch 5 / 6) train acc: 0.564000; val_acc: 0.546000
# (Epoch 6 / 6) train acc: 0.580000; val_acc: 0.550000
#
# ************************************************************
#
# SEARCH 17 : update_rule=rmsprop, reg=4.899e-04, lr=1.366e-03, num_epochs=7
#
# (Iteration 1 / 3430) loss: 2.302624
# (Epoch 0 / 7) train acc: 0.102000; val_acc: 0.095000
# (Epoch 1 / 7) train acc: 0.588000; val_acc: 0.552000
# (Epoch 2 / 7) train acc: 0.637000; val_acc: 0.577000
# (Iteration 1001 / 3430) loss: 1.094322
# (Epoch 3 / 7) train acc: 0.661000; val_acc: 0.588000
# (Epoch 4 / 7) train acc: 0.695000; val_acc: 0.593000
# (Iteration 2001 / 3430) loss: 1.064608
# (Epoch 5 / 7) train acc: 0.727000; val_acc: 0.591000
# (Epoch 6 / 7) train acc: 0.707000; val_acc: 0.585000
# (Iteration 3001 / 3430) loss: 0.972862
# (Epoch 7 / 7) train acc: 0.770000; val_acc: 0.559000
#
# ************************************************************
#
# SEARCH 18 : update_rule=rmsprop, reg=3.121e-04, lr=8.028e-03, num_epochs=8
#
# (Iteration 1 / 3920) loss: 2.302569
# (Epoch 0 / 8) train acc: 0.088000; val_acc: 0.078000
# (Epoch 1 / 8) train acc: 0.538000; val_acc: 0.505000
# (Epoch 2 / 8) train acc: 0.569000; val_acc: 0.499000
# (Iteration 1001 / 3920) loss: 1.384864
# (Epoch 3 / 8) train acc: 0.588000; val_acc: 0.551000
# (Epoch 4 / 8) train acc: 0.609000; val_acc: 0.549000
# (Iteration 2001 / 3920) loss: 1.302803
# (Epoch 5 / 8) train acc: 0.649000; val_acc: 0.526000
# (Epoch 6 / 8) train acc: 0.623000; val_acc: 0.548000
# (Iteration 3001 / 3920) loss: 1.321888
# (Epoch 7 / 8) train acc: 0.644000; val_acc: 0.559000
# (Epoch 8 / 8) train acc: 0.664000; val_acc: 0.555000
#
# ************************************************************
#
# SEARCH 19 : update_rule=rmsprop, reg=6.188e-04, lr=1.648e-03, num_epochs=7
#
# (Iteration 1 / 3430) loss: 2.302612
# (Epoch 0 / 7) train acc: 0.106000; val_acc: 0.119000
# (Epoch 1 / 7) train acc: 0.594000; val_acc: 0.544000
# (Epoch 2 / 7) train acc: 0.630000; val_acc: 0.600000
# (Iteration 1001 / 3430) loss: 1.143293
# (Epoch 3 / 7) train acc: 0.644000; val_acc: 0.580000
# (Epoch 4 / 7) train acc: 0.693000; val_acc: 0.582000
# (Iteration 2001 / 3430) loss: 0.872845
# (Epoch 5 / 7) train acc: 0.711000; val_acc: 0.569000
# (Epoch 6 / 7) train acc: 0.719000; val_acc: 0.591000
# (Iteration 3001 / 3430) loss: 0.955293
# (Epoch 7 / 7) train acc: 0.754000; val_acc: 0.581000
#
# ************************************************************
#
# SEARCH 20 : update_rule=rmsprop, reg=4.653e-04, lr=3.493e-03, num_epochs=7
#
# (Iteration 1 / 3430) loss: 2.302611
# (Epoch 0 / 7) train acc: 0.096000; val_acc: 0.079000
# (Epoch 1 / 7) train acc: 0.601000; val_acc: 0.557000
# (Epoch 2 / 7) train acc: 0.643000; val_acc: 0.569000
# (Iteration 1001 / 3430) loss: 1.059553
# (Epoch 3 / 7) train acc: 0.670000; val_acc: 0.581000
# (Epoch 4 / 7) train acc: 0.693000; val_acc: 0.564000
# (Iteration 2001 / 3430) loss: 1.228671
# (Epoch 5 / 7) train acc: 0.708000; val_acc: 0.570000
# (Epoch 6 / 7) train acc: 0.725000; val_acc: 0.559000
# (Iteration 3001 / 3430) loss: 0.941940
# (Epoch 7 / 7) train acc: 0.732000; val_acc: 0.570000
#
# ************************************************************
#
# SEARCH 21 : update_rule=rmsprop, reg=9.230e-04, lr=5.674e-04, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302636
# (Epoch 0 / 5) train acc: 0.163000; val_acc: 0.206000
# (Epoch 1 / 5) train acc: 0.565000; val_acc: 0.531000
# (Epoch 2 / 5) train acc: 0.573000; val_acc: 0.573000
# (Iteration 1001 / 2450) loss: 1.157643
# (Epoch 3 / 5) train acc: 0.594000; val_acc: 0.589000
# (Epoch 4 / 5) train acc: 0.629000; val_acc: 0.596000
# (Iteration 2001 / 2450) loss: 1.221417
# (Epoch 5 / 5) train acc: 0.637000; val_acc: 0.602000
#
# ************************************************************
#
# SEARCH 22 : update_rule=rmsprop, reg=1.170e-04, lr=6.465e-03, num_epochs=9
#
# (Iteration 1 / 4410) loss: 2.302590
# (Epoch 0 / 9) train acc: 0.112000; val_acc: 0.097000
# (Epoch 1 / 9) train acc: 0.564000; val_acc: 0.521000
# (Epoch 2 / 9) train acc: 0.597000; val_acc: 0.525000
# (Iteration 1001 / 4410) loss: 1.245637
# (Epoch 3 / 9) train acc: 0.639000; val_acc: 0.542000
# (Epoch 4 / 9) train acc: 0.671000; val_acc: 0.559000
# (Iteration 2001 / 4410) loss: 1.134035
# (Epoch 5 / 9) train acc: 0.658000; val_acc: 0.537000
# (Epoch 6 / 9) train acc: 0.697000; val_acc: 0.537000
# (Iteration 3001 / 4410) loss: 0.869196
# (Epoch 7 / 9) train acc: 0.698000; val_acc: 0.534000
# (Epoch 8 / 9) train acc: 0.720000; val_acc: 0.568000
# (Iteration 4001 / 4410) loss: 0.924907
# (Epoch 9 / 9) train acc: 0.716000; val_acc: 0.547000
#
# ************************************************************
#
# SEARCH 23 : update_rule=rmsprop, reg=3.782e-04, lr=6.779e-04, num_epochs=8
#
# (Iteration 1 / 3920) loss: 2.302654
# (Epoch 0 / 8) train acc: 0.124000; val_acc: 0.086000
# (Epoch 1 / 8) train acc: 0.563000; val_acc: 0.546000
# (Epoch 2 / 8) train acc: 0.571000; val_acc: 0.553000
# (Iteration 1001 / 3920) loss: 1.006781
# (Epoch 3 / 8) train acc: 0.605000; val_acc: 0.573000
# (Epoch 4 / 8) train acc: 0.649000; val_acc: 0.598000
# (Iteration 2001 / 3920) loss: 1.074462
# (Epoch 5 / 8) train acc: 0.662000; val_acc: 0.605000
# (Epoch 6 / 8) train acc: 0.684000; val_acc: 0.607000
# (Iteration 3001 / 3920) loss: 0.905805
# (Epoch 7 / 8) train acc: 0.701000; val_acc: 0.605000
# (Epoch 8 / 8) train acc: 0.707000; val_acc: 0.605000
#
# ************************************************************
#
# SEARCH 24 : update_rule=rmsprop, reg=1.043e-04, lr=6.588e-03, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302576
# (Epoch 0 / 5) train acc: 0.148000; val_acc: 0.120000
# (Epoch 1 / 5) train acc: 0.549000; val_acc: 0.511000
# (Epoch 2 / 5) train acc: 0.614000; val_acc: 0.548000
# (Iteration 1001 / 2450) loss: 1.103205
# (Epoch 3 / 5) train acc: 0.646000; val_acc: 0.543000
# (Epoch 4 / 5) train acc: 0.650000; val_acc: 0.537000
# (Iteration 2001 / 2450) loss: 0.991613
# (Epoch 5 / 5) train acc: 0.681000; val_acc: 0.543000
#
# ************************************************************
#
# SEARCH 25 : update_rule=rmsprop, reg=1.906e-03, lr=1.295e-03, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302648
# (Epoch 0 / 6) train acc: 0.098000; val_acc: 0.107000
# (Epoch 1 / 6) train acc: 0.591000; val_acc: 0.562000
# (Epoch 2 / 6) train acc: 0.635000; val_acc: 0.568000
# (Iteration 1001 / 2940) loss: 1.079540
# (Epoch 3 / 6) train acc: 0.647000; val_acc: 0.579000
# (Epoch 4 / 6) train acc: 0.691000; val_acc: 0.589000
# (Iteration 2001 / 2940) loss: 1.382823
# (Epoch 5 / 6) train acc: 0.650000; val_acc: 0.570000
# (Epoch 6 / 6) train acc: 0.701000; val_acc: 0.587000
#
# ************************************************************
#
# SEARCH 26 : update_rule=rmsprop, reg=1.402e-04, lr=1.401e-03, num_epochs=9
#
# (Iteration 1 / 4410) loss: 2.302591
# (Epoch 0 / 9) train acc: 0.102000; val_acc: 0.107000
# (Epoch 1 / 9) train acc: 0.588000; val_acc: 0.555000
# (Epoch 2 / 9) train acc: 0.639000; val_acc: 0.582000
# (Iteration 1001 / 4410) loss: 1.065216
# (Epoch 3 / 9) train acc: 0.705000; val_acc: 0.587000
# (Epoch 4 / 9) train acc: 0.727000; val_acc: 0.594000
# (Iteration 2001 / 4410) loss: 0.927130
# (Epoch 5 / 9) train acc: 0.727000; val_acc: 0.595000
# (Epoch 6 / 9) train acc: 0.760000; val_acc: 0.593000
# (Iteration 3001 / 4410) loss: 0.910832
# (Epoch 7 / 9) train acc: 0.759000; val_acc: 0.573000
# (Epoch 8 / 9) train acc: 0.773000; val_acc: 0.573000
# (Iteration 4001 / 4410) loss: 0.908463
# (Epoch 9 / 9) train acc: 0.804000; val_acc: 0.574000
#
# ************************************************************
#
# SEARCH 27 : update_rule=rmsprop, reg=5.822e-03, lr=3.860e-04, num_epochs=6
#
# (Iteration 1 / 2940) loss: 2.302807
# (Epoch 0 / 6) train acc: 0.109000; val_acc: 0.112000
# (Epoch 1 / 6) train acc: 0.521000; val_acc: 0.523000
# (Epoch 2 / 6) train acc: 0.570000; val_acc: 0.534000
# (Iteration 1001 / 2940) loss: 1.323985
# (Epoch 3 / 6) train acc: 0.578000; val_acc: 0.560000
# (Epoch 4 / 6) train acc: 0.564000; val_acc: 0.548000
# (Iteration 2001 / 2940) loss: 1.305522
# (Epoch 5 / 6) train acc: 0.568000; val_acc: 0.576000
# (Epoch 6 / 6) train acc: 0.576000; val_acc: 0.559000
#
# ************************************************************
#
# SEARCH 28 : update_rule=rmsprop, reg=4.772e-04, lr=5.632e-03, num_epochs=10
#
# (Iteration 1 / 4900) loss: 2.302593
# (Epoch 0 / 10) train acc: 0.105000; val_acc: 0.113000
# (Epoch 1 / 10) train acc: 0.580000; val_acc: 0.518000
# (Epoch 2 / 10) train acc: 0.594000; val_acc: 0.568000
# (Iteration 1001 / 4900) loss: 1.175221
# (Epoch 3 / 10) train acc: 0.605000; val_acc: 0.534000
# (Epoch 4 / 10) train acc: 0.656000; val_acc: 0.521000
# (Iteration 2001 / 4900) loss: 0.981991
# (Epoch 5 / 10) train acc: 0.673000; val_acc: 0.549000
# (Epoch 6 / 10) train acc: 0.681000; val_acc: 0.557000
# (Iteration 3001 / 4900) loss: 1.121054
# (Epoch 7 / 10) train acc: 0.686000; val_acc: 0.556000
# (Epoch 8 / 10) train acc: 0.674000; val_acc: 0.545000
# (Iteration 4001 / 4900) loss: 1.348020
# (Epoch 9 / 10) train acc: 0.681000; val_acc: 0.578000
# (Epoch 10 / 10) train acc: 0.706000; val_acc: 0.570000
#
# ************************************************************
#
# SEARCH 29 : update_rule=rmsprop, reg=2.952e-03, lr=4.091e-03, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302713
# (Epoch 0 / 5) train acc: 0.082000; val_acc: 0.098000
# (Epoch 1 / 5) train acc: 0.579000; val_acc: 0.525000
# (Epoch 2 / 5) train acc: 0.591000; val_acc: 0.553000
# (Iteration 1001 / 2450) loss: 1.395774
# (Epoch 3 / 5) train acc: 0.584000; val_acc: 0.551000
# (Epoch 4 / 5) train acc: 0.586000; val_acc: 0.582000
# (Iteration 2001 / 2450) loss: 1.198772
# (Epoch 5 / 5) train acc: 0.605000; val_acc: 0.550000
#
# ************************************************************
#
# SEARCH 30 : update_rule=rmsprop, reg=3.158e-03, lr=6.894e-04, num_epochs=5
#
# (Iteration 1 / 2450) loss: 2.302680
# (Epoch 0 / 5) train acc: 0.112000; val_acc: 0.127000
# (Epoch 1 / 5) train acc: 0.548000; val_acc: 0.531000
# (Epoch 2 / 5) train acc: 0.587000; val_acc: 0.556000
# (Iteration 1001 / 2450) loss: 1.597868
# (Epoch 3 / 5) train acc: 0.610000; val_acc: 0.563000
# (Epoch 4 / 5) train acc: 0.635000; val_acc: 0.583000
# (Iteration 2001 / 2450) loss: 1.261706
# (Epoch 5 / 5) train acc: 0.640000; val_acc: 0.569000
#
# ************************************************************
#
# The best model's validation accuracy is 0.625 with the following hyperparameters:
# update_rule=rmsprop, reg=1.886e-04, lr=4.442e-04, num_epochs=10

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.57
