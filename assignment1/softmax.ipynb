# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = "cs231n/assignments/assignment1/"
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]

    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image

    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.373655
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$
#
# Softmax 함수에서 Li = -log(probability) 이다.
#
# our loss 값은: <Li의 평균> + regularization
#
# 여기서 regularization은 현재 0 이고,
#
# 클래스 갯수가 10개이므로, 학습전에 probability는 1/10에 수렴할것이고,
#
# <Li의 평균> 은 -log(0.1)에 수렴하는것

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 3.104068 analytic: 3.104068, relative error: 2.322386e-08
# numerical: -3.449415 analytic: -3.449415, relative error: 6.249712e-09
# numerical: 1.208475 analytic: 1.208475, relative error: 6.747364e-08
# numerical: 1.027255 analytic: 1.027255, relative error: 3.069486e-08
# numerical: 2.578389 analytic: 2.578389, relative error: 2.465659e-10
# numerical: -0.413683 analytic: -0.413683, relative error: 4.076896e-08
# numerical: -0.155197 analytic: -0.155197, relative error: 2.176446e-07
# numerical: 1.915936 analytic: 1.915936, relative error: 3.121777e-08
# numerical: 0.721311 analytic: 0.721311, relative error: 8.596674e-08
# numerical: 0.202630 analytic: 0.202630, relative error: 1.457060e-07
# numerical: 1.864898 analytic: 1.864898, relative error: 7.871318e-09
# numerical: 0.124762 analytic: 0.124762, relative error: 9.084155e-08
# numerical: -1.440604 analytic: -1.440604, relative error: 4.534556e-08
# numerical: -3.464566 analytic: -3.464566, relative error: 2.222912e-09
# numerical: 0.992189 analytic: 0.992188, relative error: 9.194524e-08
# numerical: 0.298184 analytic: 0.298184, relative error: 1.421875e-07
# numerical: 0.902276 analytic: 0.902276, relative error: 1.467670e-08
# numerical: 0.706602 analytic: 0.706602, relative error: 5.121980e-08
# numerical: -2.693444 analytic: -2.693444, relative error: 3.327521e-08
# numerical: -2.462770 analytic: -2.462770, relative error: 6.177955e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.373655e+00 computed in 0.142195s
# vectorized loss: 2.373655e+00 computed in 0.017261s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = np.geomspace(5e-7, 15e-7, 7)
regularization_strengths = np.geomspace(7e3, 5e4, 7)

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

verbose = True
tik = time.time()

for lr in learning_rates:
  for rs in regularization_strengths:
    softmax = Softmax() # 초기화
    loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=rs,
                          num_iters=1500, verbose=verbose) # train
    y_train_pred = softmax.predict(X_train)
    train_accuracy = np.mean(y_train == y_train_pred)
    y_val_pred = softmax.predict(X_val)
    val_accuracy = np.mean(y_val == y_val_pred)

    results[(lr,rs)] = (train_accuracy, val_accuracy)

    if val_accuracy > best_val:
      best_val = val_accuracy
      best_softmax = softmax

tok = time.time()
print(f"It took {tok-tik:.1f} seconds.")

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# ---------- 5.0e-07 7.0e+03 ----------
# iteration 0 / 1500: loss 222.070149
# iteration 100 / 1500: loss 54.965048
# iteration 200 / 1500: loss 14.840869
# iteration 300 / 1500: loss 5.066206
# iteration 400 / 1500: loss 2.760965
# iteration 500 / 1500: loss 2.093426
# iteration 600 / 1500: loss 2.065595
# iteration 700 / 1500: loss 1.987737
# iteration 800 / 1500: loss 1.967480
# iteration 900 / 1500: loss 1.933876
# iteration 1000 / 1500: loss 1.899975
# iteration 1100 / 1500: loss 2.002237
# iteration 1200 / 1500: loss 2.022998
# iteration 1300 / 1500: loss 1.973031
# iteration 1400 / 1500: loss 1.906667
# iteration 1499 / 1500: loss 2.010549
#
# ---------- 5.0e-07 9.7e+03 ----------
# iteration 0 / 1500: loss 308.378972
# iteration 100 / 1500: loss 44.555233
# iteration 200 / 1500: loss 7.977456
# iteration 300 / 1500: loss 2.869649
# iteration 400 / 1500: loss 2.121647
# iteration 500 / 1500: loss 2.046437
# iteration 600 / 1500: loss 1.943140
# iteration 700 / 1500: loss 1.992814
# iteration 800 / 1500: loss 2.051807
# iteration 900 / 1500: loss 1.988612
# iteration 1000 / 1500: loss 2.044819
# iteration 1100 / 1500: loss 1.942333
# iteration 1200 / 1500: loss 1.926268
# iteration 1300 / 1500: loss 2.035161
# iteration 1400 / 1500: loss 2.008604
# iteration 1499 / 1500: loss 2.003738
#
# ---------- 5.0e-07 1.3e+04 ----------
# iteration 0 / 1500: loss 413.946951
# iteration 100 / 1500: loss 28.909097
# iteration 200 / 1500: loss 3.773545
# iteration 300 / 1500: loss 2.147225
# iteration 400 / 1500: loss 2.075193
# iteration 500 / 1500: loss 2.043482
# iteration 600 / 1500: loss 2.075233
# iteration 700 / 1500: loss 2.027236
# iteration 800 / 1500: loss 2.101329
# iteration 900 / 1500: loss 2.052444
# iteration 1000 / 1500: loss 2.065609
# iteration 1100 / 1500: loss 2.022268
# iteration 1200 / 1500: loss 2.027952
# iteration 1300 / 1500: loss 1.996018
# iteration 1400 / 1500: loss 2.055373
# iteration 1499 / 1500: loss 1.992815
#
# ---------- 5.0e-07 1.9e+04 ----------
# iteration 0 / 1500: loss 583.873047
# iteration 100 / 1500: loss 15.169362
# iteration 200 / 1500: loss 2.352005
# iteration 300 / 1500: loss 2.074337
# iteration 400 / 1500: loss 2.063224
# iteration 500 / 1500: loss 2.094461
# iteration 600 / 1500: loss 2.049801
# iteration 700 / 1500: loss 2.169474
# iteration 800 / 1500: loss 2.056879
# iteration 900 / 1500: loss 2.061902
# iteration 1000 / 1500: loss 2.121922
# iteration 1100 / 1500: loss 2.026275
# iteration 1200 / 1500: loss 2.074651
# iteration 1300 / 1500: loss 2.075065
# iteration 1400 / 1500: loss 2.061615
# iteration 1499 / 1500: loss 2.060493
#
# ---------- 5.0e-07 2.6e+04 ----------
# iteration 0 / 1500: loss 799.043886
# iteration 100 / 1500: loss 6.208853
# iteration 200 / 1500: loss 2.121678
# iteration 300 / 1500: loss 2.127043
# iteration 400 / 1500: loss 2.086558
# iteration 500 / 1500: loss 2.073977
# iteration 600 / 1500: loss 2.094001
# iteration 700 / 1500: loss 2.066061
# iteration 800 / 1500: loss 2.066486
# iteration 900 / 1500: loss 2.079075
# iteration 1000 / 1500: loss 2.139328
# iteration 1100 / 1500: loss 2.081717
# iteration 1200 / 1500: loss 2.035569
# iteration 1300 / 1500: loss 2.105404
# iteration 1400 / 1500: loss 2.000225
# iteration 1499 / 1500: loss 2.083775
#
# ---------- 5.0e-07 3.6e+04 ----------
# iteration 0 / 1500: loss 1110.791235
# iteration 100 / 1500: loss 2.814267
# iteration 200 / 1500: loss 2.096478
# iteration 300 / 1500: loss 2.129846
# iteration 400 / 1500: loss 2.173424
# iteration 500 / 1500: loss 2.145489
# iteration 600 / 1500: loss 2.125277
# iteration 700 / 1500: loss 2.090036
# iteration 800 / 1500: loss 2.099492
# iteration 900 / 1500: loss 2.107619
# iteration 1000 / 1500: loss 2.126259
# iteration 1100 / 1500: loss 2.144299
# iteration 1200 / 1500: loss 2.081373
# iteration 1300 / 1500: loss 2.118478
# iteration 1400 / 1500: loss 2.088707
# iteration 1499 / 1500: loss 2.122595
#
# ---------- 5.0e-07 5.0e+04 ----------
# iteration 0 / 1500: loss 1567.222378
# iteration 100 / 1500: loss 2.201720
# iteration 200 / 1500: loss 2.177027
# iteration 300 / 1500: loss 2.168815
# iteration 400 / 1500: loss 2.155271
# iteration 500 / 1500: loss 2.162959
# iteration 600 / 1500: loss 2.146755
# iteration 700 / 1500: loss 2.140224
# iteration 800 / 1500: loss 2.155055
# iteration 900 / 1500: loss 2.187544
# iteration 1000 / 1500: loss 2.149506
# iteration 1100 / 1500: loss 2.173097
# iteration 1200 / 1500: loss 2.147496
# iteration 1300 / 1500: loss 2.165241
# iteration 1400 / 1500: loss 2.164404
# iteration 1499 / 1500: loss 2.136849
#
# ---------- 6.0e-07 7.0e+03 ----------
# iteration 0 / 1500: loss 218.471909
# iteration 100 / 1500: loss 41.207000
# iteration 200 / 1500: loss 9.130240
# iteration 300 / 1500: loss 3.256223
# iteration 400 / 1500: loss 2.203920
# iteration 500 / 1500: loss 2.032478
# iteration 600 / 1500: loss 2.072836
# iteration 700 / 1500: loss 2.059865
# iteration 800 / 1500: loss 1.998079
# iteration 900 / 1500: loss 1.947999
# iteration 1000 / 1500: loss 1.948216
# iteration 1100 / 1500: loss 1.905618
# iteration 1200 / 1500: loss 1.953136
# iteration 1300 / 1500: loss 1.988508
# iteration 1400 / 1500: loss 1.943322
# iteration 1499 / 1500: loss 2.011223
#
# ---------- 6.0e-07 9.7e+03 ----------
# iteration 0 / 1500: loss 301.107776
# iteration 100 / 1500: loss 30.149239
# iteration 200 / 1500: loss 4.729696
# iteration 300 / 1500: loss 2.331154
# iteration 400 / 1500: loss 1.965519
# iteration 500 / 1500: loss 2.002261
# iteration 600 / 1500: loss 2.053555
# iteration 700 / 1500: loss 2.047639
# iteration 800 / 1500: loss 2.049039
# iteration 900 / 1500: loss 2.035650
# iteration 1000 / 1500: loss 2.003339
# iteration 1100 / 1500: loss 2.025141
# iteration 1200 / 1500: loss 1.982773
# iteration 1300 / 1500: loss 2.104722
# iteration 1400 / 1500: loss 2.072438
# iteration 1499 / 1500: loss 2.015005
#
# ---------- 6.0e-07 1.3e+04 ----------
# iteration 0 / 1500: loss 422.195717
# iteration 100 / 1500: loss 17.828394
# iteration 200 / 1500: loss 2.700487
# iteration 300 / 1500: loss 2.121600
# iteration 400 / 1500: loss 2.094669
# iteration 500 / 1500: loss 2.020803
# iteration 600 / 1500: loss 2.059412
# iteration 700 / 1500: loss 2.054634
# iteration 800 / 1500: loss 2.136980
# iteration 900 / 1500: loss 2.005607
# iteration 1000 / 1500: loss 2.045449
# iteration 1100 / 1500: loss 2.003393
# iteration 1200 / 1500: loss 2.048967
# iteration 1300 / 1500: loss 2.048354
# iteration 1400 / 1500: loss 2.096957
# iteration 1499 / 1500: loss 2.026992
#
# ---------- 6.0e-07 1.9e+04 ----------
# iteration 0 / 1500: loss 587.179176
# iteration 100 / 1500: loss 8.155736
# iteration 200 / 1500: loss 2.097627
# iteration 300 / 1500: loss 2.049972
# iteration 400 / 1500: loss 2.073414
# iteration 500 / 1500: loss 2.074969
# iteration 600 / 1500: loss 2.037198
# iteration 700 / 1500: loss 1.957890
# iteration 800 / 1500: loss 2.036750
# iteration 900 / 1500: loss 2.054018
# iteration 1000 / 1500: loss 2.010322
# iteration 1100 / 1500: loss 2.065763
# iteration 1200 / 1500: loss 2.089440
# iteration 1300 / 1500: loss 2.130458
# iteration 1400 / 1500: loss 2.080406
# iteration 1499 / 1500: loss 2.036032
#
# ---------- 6.0e-07 2.6e+04 ----------
# iteration 0 / 1500: loss 807.121499
# iteration 100 / 1500: loss 3.403473
# iteration 200 / 1500: loss 2.037537
# iteration 300 / 1500: loss 2.086722
# iteration 400 / 1500: loss 2.111562
# iteration 500 / 1500: loss 2.096258
# iteration 600 / 1500: loss 2.095607
# iteration 700 / 1500: loss 2.174426
# iteration 800 / 1500: loss 2.082359
# iteration 900 / 1500: loss 2.038612
# iteration 1000 / 1500: loss 2.049232
# iteration 1100 / 1500: loss 2.111961
# iteration 1200 / 1500: loss 2.092450
# iteration 1300 / 1500: loss 2.097362
# iteration 1400 / 1500: loss 2.158641
# iteration 1499 / 1500: loss 2.112759
#
# ---------- 6.0e-07 3.6e+04 ----------
# iteration 0 / 1500: loss 1108.143785
# iteration 100 / 1500: loss 2.243337
# iteration 200 / 1500: loss 2.128375
# iteration 300 / 1500: loss 2.142183
# iteration 400 / 1500: loss 2.130705
# iteration 500 / 1500: loss 2.140669
# iteration 600 / 1500: loss 2.130802
# iteration 700 / 1500: loss 2.150834
# iteration 800 / 1500: loss 2.123959
# iteration 900 / 1500: loss 2.091547
# iteration 1000 / 1500: loss 2.149591
# iteration 1100 / 1500: loss 2.091016
# iteration 1200 / 1500: loss 2.084977
# iteration 1300 / 1500: loss 2.144610
# iteration 1400 / 1500: loss 2.067437
# iteration 1499 / 1500: loss 2.095671
#
# ---------- 6.0e-07 5.0e+04 ----------
# iteration 0 / 1500: loss 1543.492806
# iteration 100 / 1500: loss 2.200706
# iteration 200 / 1500: loss 2.147438
# iteration 300 / 1500: loss 2.111868
# iteration 400 / 1500: loss 2.164304
# iteration 500 / 1500: loss 2.154270
# iteration 600 / 1500: loss 2.151876
# iteration 700 / 1500: loss 2.119479
# iteration 800 / 1500: loss 2.150007
# iteration 900 / 1500: loss 2.198170
# iteration 1000 / 1500: loss 2.154490
# iteration 1100 / 1500: loss 2.111583
# iteration 1200 / 1500: loss 2.166795
# iteration 1300 / 1500: loss 2.102261
# iteration 1400 / 1500: loss 2.147758
# iteration 1499 / 1500: loss 2.131365
#
# ---------- 7.2e-07 7.0e+03 ----------
# iteration 0 / 1500: loss 218.440776
# iteration 100 / 1500: loss 29.708574
# iteration 200 / 1500: loss 5.574575
# iteration 300 / 1500: loss 2.509710
# iteration 400 / 1500: loss 2.113445
# iteration 500 / 1500: loss 1.968548
# iteration 600 / 1500: loss 1.999770
# iteration 700 / 1500: loss 2.013999
# iteration 800 / 1500: loss 1.943896
# iteration 900 / 1500: loss 2.056126
# iteration 1000 / 1500: loss 1.956404
# iteration 1100 / 1500: loss 2.065888
# iteration 1200 / 1500: loss 1.968614
# iteration 1300 / 1500: loss 2.014738
# iteration 1400 / 1500: loss 1.958550
# iteration 1499 / 1500: loss 2.009777
#
# ---------- 7.2e-07 9.7e+03 ----------
# iteration 0 / 1500: loss 305.218744
# iteration 100 / 1500: loss 19.601563
# iteration 200 / 1500: loss 3.135148
# iteration 300 / 1500: loss 2.044467
# iteration 400 / 1500: loss 1.976111
# iteration 500 / 1500: loss 2.021946
# iteration 600 / 1500: loss 1.998781
# iteration 700 / 1500: loss 1.863501
# iteration 800 / 1500: loss 1.970028
# iteration 900 / 1500: loss 2.039113
# iteration 1000 / 1500: loss 2.010010
# iteration 1100 / 1500: loss 1.983058
# iteration 1200 / 1500: loss 1.954428
# iteration 1300 / 1500: loss 2.049633
# iteration 1400 / 1500: loss 1.995383
# iteration 1499 / 1500: loss 1.996523
#
# ---------- 7.2e-07 1.3e+04 ----------
# iteration 0 / 1500: loss 419.682272
# iteration 100 / 1500: loss 10.049934
# iteration 200 / 1500: loss 2.208903
# iteration 300 / 1500: loss 2.073123
# iteration 400 / 1500: loss 2.077118
# iteration 500 / 1500: loss 2.010316
# iteration 600 / 1500: loss 2.063791
# iteration 700 / 1500: loss 2.089785
# iteration 800 / 1500: loss 2.022397
# iteration 900 / 1500: loss 2.033182
# iteration 1000 / 1500: loss 2.098386
# iteration 1100 / 1500: loss 2.063915
# iteration 1200 / 1500: loss 2.043746
# iteration 1300 / 1500: loss 2.022260
# iteration 1400 / 1500: loss 1.979556
# iteration 1499 / 1500: loss 2.036801
#
# ---------- 7.2e-07 1.9e+04 ----------
# iteration 0 / 1500: loss 571.434550
# iteration 100 / 1500: loss 4.440385
# iteration 200 / 1500: loss 2.016159
# iteration 300 / 1500: loss 2.088287
# iteration 400 / 1500: loss 2.087499
# iteration 500 / 1500: loss 2.011556
# iteration 600 / 1500: loss 2.038768
# iteration 700 / 1500: loss 2.092481
# iteration 800 / 1500: loss 2.032886
# iteration 900 / 1500: loss 2.090154
# iteration 1000 / 1500: loss 2.027367
# iteration 1100 / 1500: loss 2.063764
# iteration 1200 / 1500: loss 2.094978
# iteration 1300 / 1500: loss 2.133016
# iteration 1400 / 1500: loss 2.062464
# iteration 1499 / 1500: loss 2.081726
#
# ---------- 7.2e-07 2.6e+04 ----------
# iteration 0 / 1500: loss 809.363041
# iteration 100 / 1500: loss 2.449669
# iteration 200 / 1500: loss 2.085228
# iteration 300 / 1500: loss 2.148253
# iteration 400 / 1500: loss 2.066186
# iteration 500 / 1500: loss 2.027733
# iteration 600 / 1500: loss 2.087734
# iteration 700 / 1500: loss 2.113824
# iteration 800 / 1500: loss 2.081863
# iteration 900 / 1500: loss 2.055415
# iteration 1000 / 1500: loss 2.097248
# iteration 1100 / 1500: loss 2.063672
# iteration 1200 / 1500: loss 2.069062
# iteration 1300 / 1500: loss 2.091227
# iteration 1400 / 1500: loss 2.127087
# iteration 1499 / 1500: loss 2.142346
#
# ---------- 7.2e-07 3.6e+04 ----------
# iteration 0 / 1500: loss 1102.981237
# iteration 100 / 1500: loss 2.159826
# iteration 200 / 1500: loss 2.134077
# iteration 300 / 1500: loss 2.108416
# iteration 400 / 1500: loss 2.097402
# iteration 500 / 1500: loss 2.150869
# iteration 600 / 1500: loss 2.039848
# iteration 700 / 1500: loss 2.146373
# iteration 800 / 1500: loss 2.126719
# iteration 900 / 1500: loss 2.112063
# iteration 1000 / 1500: loss 2.100370
# iteration 1100 / 1500: loss 2.066264
# iteration 1200 / 1500: loss 2.100318
# iteration 1300 / 1500: loss 2.131628
# iteration 1400 / 1500: loss 2.140201
# iteration 1499 / 1500: loss 2.134326
#
# ---------- 7.2e-07 5.0e+04 ----------
# iteration 0 / 1500: loss 1532.667377
# iteration 100 / 1500: loss 2.163691
# iteration 200 / 1500: loss 2.081675
# iteration 300 / 1500: loss 2.113032
# iteration 400 / 1500: loss 2.113564
# iteration 500 / 1500: loss 2.155984
# iteration 600 / 1500: loss 2.173254
# iteration 700 / 1500: loss 2.136815
# iteration 800 / 1500: loss 2.157281
# iteration 900 / 1500: loss 2.142470
# iteration 1000 / 1500: loss 2.179709
# iteration 1100 / 1500: loss 2.175046
# iteration 1200 / 1500: loss 2.119018
# iteration 1300 / 1500: loss 2.091291
# iteration 1400 / 1500: loss 2.153278
# iteration 1499 / 1500: loss 2.155947
#
# ---------- 8.7e-07 7.0e+03 ----------
# iteration 0 / 1500: loss 218.467242
# iteration 100 / 1500: loss 20.314860
# iteration 200 / 1500: loss 3.603196
# iteration 300 / 1500: loss 2.108102
# iteration 400 / 1500: loss 1.992578
# iteration 500 / 1500: loss 1.980018
# iteration 600 / 1500: loss 1.966812
# iteration 700 / 1500: loss 1.951519
# iteration 800 / 1500: loss 2.014831
# iteration 900 / 1500: loss 2.049507
# iteration 1000 / 1500: loss 2.033492
# iteration 1100 / 1500: loss 1.984226
# iteration 1200 / 1500: loss 1.976272
# iteration 1300 / 1500: loss 1.963846
# iteration 1400 / 1500: loss 1.956383
# iteration 1499 / 1500: loss 2.017752
#
# ---------- 8.7e-07 9.7e+03 ----------
# iteration 0 / 1500: loss 300.290496
# iteration 100 / 1500: loss 11.851809
# iteration 200 / 1500: loss 2.356505
# iteration 300 / 1500: loss 1.970772
# iteration 400 / 1500: loss 2.055110
# iteration 500 / 1500: loss 1.938395
# iteration 600 / 1500: loss 2.015074
# iteration 700 / 1500: loss 2.000840
# iteration 800 / 1500: loss 2.017882
# iteration 900 / 1500: loss 2.102274
# iteration 1000 / 1500: loss 2.055635
# iteration 1100 / 1500: loss 2.082239
# iteration 1200 / 1500: loss 2.014105
# iteration 1300 / 1500: loss 2.021410
# iteration 1400 / 1500: loss 1.959310
# iteration 1499 / 1500: loss 2.014826
#
# ---------- 8.7e-07 1.3e+04 ----------
# iteration 0 / 1500: loss 417.879227
# iteration 100 / 1500: loss 5.739657
# iteration 200 / 1500: loss 2.036887
# iteration 300 / 1500: loss 1.967357
# iteration 400 / 1500: loss 2.077179
# iteration 500 / 1500: loss 1.996439
# iteration 600 / 1500: loss 1.994469
# iteration 700 / 1500: loss 2.033420
# iteration 800 / 1500: loss 1.974874
# iteration 900 / 1500: loss 2.022652
# iteration 1000 / 1500: loss 1.995061
# iteration 1100 / 1500: loss 1.981421
# iteration 1200 / 1500: loss 2.038988
# iteration 1300 / 1500: loss 2.060648
# iteration 1400 / 1500: loss 1.987234
# iteration 1499 / 1500: loss 2.030454
#
# ---------- 8.7e-07 1.9e+04 ----------
# iteration 0 / 1500: loss 586.973587
# iteration 100 / 1500: loss 2.827732
# iteration 200 / 1500: loss 2.085950
# iteration 300 / 1500: loss 2.066141
# iteration 400 / 1500: loss 2.057652
# iteration 500 / 1500: loss 2.056492
# iteration 600 / 1500: loss 2.064435
# iteration 700 / 1500: loss 2.066201
# iteration 800 / 1500: loss 2.063916
# iteration 900 / 1500: loss 2.075060
# iteration 1000 / 1500: loss 2.034573
# iteration 1100 / 1500: loss 2.036403
# iteration 1200 / 1500: loss 2.039010
# iteration 1300 / 1500: loss 2.099444
# iteration 1400 / 1500: loss 2.087270
# iteration 1499 / 1500: loss 2.092559
#
# ---------- 8.7e-07 2.6e+04 ----------
# iteration 0 / 1500: loss 794.501195
# iteration 100 / 1500: loss 2.183277
# iteration 200 / 1500: loss 2.109785
# iteration 300 / 1500: loss 2.096546
# iteration 400 / 1500: loss 2.088950
# iteration 500 / 1500: loss 2.088822
# iteration 600 / 1500: loss 2.066421
# iteration 700 / 1500: loss 2.029395
# iteration 800 / 1500: loss 2.068936
# iteration 900 / 1500: loss 2.157706
# iteration 1000 / 1500: loss 2.122834
# iteration 1100 / 1500: loss 2.123795
# iteration 1200 / 1500: loss 2.045068
# iteration 1300 / 1500: loss 2.079458
# iteration 1400 / 1500: loss 2.087252
# iteration 1499 / 1500: loss 2.126430
#
# ---------- 8.7e-07 3.6e+04 ----------
# iteration 0 / 1500: loss 1115.899989
# iteration 100 / 1500: loss 2.129674
# iteration 200 / 1500: loss 2.118161
# iteration 300 / 1500: loss 2.107517
# iteration 400 / 1500: loss 2.120335
# iteration 500 / 1500: loss 2.100289
# iteration 600 / 1500: loss 2.096356
# iteration 700 / 1500: loss 2.144765
# iteration 800 / 1500: loss 2.122511
# iteration 900 / 1500: loss 2.125574
# iteration 1000 / 1500: loss 2.160356
# iteration 1100 / 1500: loss 2.116493
# iteration 1200 / 1500: loss 2.128461
# iteration 1300 / 1500: loss 2.083928
# iteration 1400 / 1500: loss 2.154313
# iteration 1499 / 1500: loss 2.099891
#
# ---------- 8.7e-07 5.0e+04 ----------
# iteration 0 / 1500: loss 1562.538520
# iteration 100 / 1500: loss 2.176968
# iteration 200 / 1500: loss 2.110391
# iteration 300 / 1500: loss 2.137696
# iteration 400 / 1500: loss 2.201787
# iteration 500 / 1500: loss 2.139059
# iteration 600 / 1500: loss 2.173126
# iteration 700 / 1500: loss 2.153085
# iteration 800 / 1500: loss 2.170281
# iteration 900 / 1500: loss 2.179049
# iteration 1000 / 1500: loss 2.124555
# iteration 1100 / 1500: loss 2.164942
# iteration 1200 / 1500: loss 2.200755
# iteration 1300 / 1500: loss 2.212558
# iteration 1400 / 1500: loss 2.158072
# iteration 1499 / 1500: loss 2.160164
#
# ---------- 1.0e-06 7.0e+03 ----------
# iteration 0 / 1500: loss 220.498889
# iteration 100 / 1500: loss 13.310748
# iteration 200 / 1500: loss 2.552362
# iteration 300 / 1500: loss 2.052801
# iteration 400 / 1500: loss 2.010474
# iteration 500 / 1500: loss 2.026027
# iteration 600 / 1500: loss 2.026389
# iteration 700 / 1500: loss 1.988620
# iteration 800 / 1500: loss 2.024457
# iteration 900 / 1500: loss 2.035887
# iteration 1000 / 1500: loss 1.888580
# iteration 1100 / 1500: loss 2.033206
# iteration 1200 / 1500: loss 1.970394
# iteration 1300 / 1500: loss 2.020901
# iteration 1400 / 1500: loss 2.028288
# iteration 1499 / 1500: loss 1.970302
#
# ---------- 1.0e-06 9.7e+03 ----------
# iteration 0 / 1500: loss 299.693518
# iteration 100 / 1500: loss 6.955827
# iteration 200 / 1500: loss 2.116453
# iteration 300 / 1500: loss 2.008336
# iteration 400 / 1500: loss 1.954047
# iteration 500 / 1500: loss 1.971861
# iteration 600 / 1500: loss 1.984921
# iteration 700 / 1500: loss 1.954473
# iteration 800 / 1500: loss 2.050221
# iteration 900 / 1500: loss 2.000883
# iteration 1000 / 1500: loss 1.992741
# iteration 1100 / 1500: loss 1.949704
# iteration 1200 / 1500: loss 1.953290
# iteration 1300 / 1500: loss 2.016454
# iteration 1400 / 1500: loss 1.973204
# iteration 1499 / 1500: loss 1.951752
#
# ---------- 1.0e-06 1.3e+04 ----------
# iteration 0 / 1500: loss 423.159361
# iteration 100 / 1500: loss 3.516035
# iteration 200 / 1500: loss 2.081369
# iteration 300 / 1500: loss 2.095787
# iteration 400 / 1500: loss 2.016595
# iteration 500 / 1500: loss 2.050533
# iteration 600 / 1500: loss 2.042962
# iteration 700 / 1500: loss 2.068508
# iteration 800 / 1500: loss 2.029989
# iteration 900 / 1500: loss 2.120222
# iteration 1000 / 1500: loss 2.061800
# iteration 1100 / 1500: loss 2.055946
# iteration 1200 / 1500: loss 2.080120
# iteration 1300 / 1500: loss 2.035500
# iteration 1400 / 1500: loss 2.010791
# iteration 1499 / 1500: loss 2.037789
#
# ---------- 1.0e-06 1.9e+04 ----------
# iteration 0 / 1500: loss 585.852328
# iteration 100 / 1500: loss 2.241637
# iteration 200 / 1500: loss 2.006105
# iteration 300 / 1500: loss 2.097359
# iteration 400 / 1500: loss 2.112912
# iteration 500 / 1500: loss 2.111271
# iteration 600 / 1500: loss 2.006332
# iteration 700 / 1500: loss 2.019825
# iteration 800 / 1500: loss 2.065482
# iteration 900 / 1500: loss 2.059825
# iteration 1000 / 1500: loss 2.051608
# iteration 1100 / 1500: loss 2.083964
# iteration 1200 / 1500: loss 2.062274
# iteration 1300 / 1500: loss 2.050533
# iteration 1400 / 1500: loss 2.076889
# iteration 1499 / 1500: loss 2.094723
#
# ---------- 1.0e-06 2.6e+04 ----------
# iteration 0 / 1500: loss 808.756523
# iteration 100 / 1500: loss 2.077597
# iteration 200 / 1500: loss 2.096272
# iteration 300 / 1500: loss 2.103991
# iteration 400 / 1500: loss 2.105551
# iteration 500 / 1500: loss 2.084049
# iteration 600 / 1500: loss 2.100784
# iteration 700 / 1500: loss 2.042003
# iteration 800 / 1500: loss 2.110378
# iteration 900 / 1500: loss 2.139645
# iteration 1000 / 1500: loss 2.089629
# iteration 1100 / 1500: loss 2.053859
# iteration 1200 / 1500: loss 2.111420
# iteration 1300 / 1500: loss 2.080015
# iteration 1400 / 1500: loss 2.038586
# iteration 1499 / 1500: loss 2.137021
#
# ---------- 1.0e-06 3.6e+04 ----------
# iteration 0 / 1500: loss 1126.881373
# iteration 100 / 1500: loss 2.145740
# iteration 200 / 1500: loss 2.112089
# iteration 300 / 1500: loss 2.105830
# iteration 400 / 1500: loss 2.166632
# iteration 500 / 1500: loss 2.152854
# iteration 600 / 1500: loss 2.145346
# iteration 700 / 1500: loss 2.136281
# iteration 800 / 1500: loss 2.100867
# iteration 900 / 1500: loss 2.070248
# iteration 1000 / 1500: loss 2.079858
# iteration 1100 / 1500: loss 2.119090
# iteration 1200 / 1500: loss 2.114112
# iteration 1300 / 1500: loss 2.155893
# iteration 1400 / 1500: loss 2.195990
# iteration 1499 / 1500: loss 2.093315
#
# ---------- 1.0e-06 5.0e+04 ----------
# iteration 0 / 1500: loss 1521.327629
# iteration 100 / 1500: loss 2.182568
# iteration 200 / 1500: loss 2.139330
# iteration 300 / 1500: loss 2.133333
# iteration 400 / 1500: loss 2.149748
# iteration 500 / 1500: loss 2.140965
# iteration 600 / 1500: loss 2.186021
# iteration 700 / 1500: loss 2.161824
# iteration 800 / 1500: loss 2.143975
# iteration 900 / 1500: loss 2.181381
# iteration 1000 / 1500: loss 2.171020
# iteration 1100 / 1500: loss 2.128969
# iteration 1200 / 1500: loss 2.121272
# iteration 1300 / 1500: loss 2.168917
# iteration 1400 / 1500: loss 2.131821
# iteration 1499 / 1500: loss 2.182376
#
# ---------- 1.2e-06 7.0e+03 ----------
# iteration 0 / 1500: loss 224.731956
# iteration 100 / 1500: loss 8.320738
# iteration 200 / 1500: loss 2.118935
# iteration 300 / 1500: loss 2.060414
# iteration 400 / 1500: loss 2.084933
# iteration 500 / 1500: loss 1.985015
# iteration 600 / 1500: loss 1.999868
# iteration 700 / 1500: loss 1.976457
# iteration 800 / 1500: loss 1.927355
# iteration 900 / 1500: loss 2.001627
# iteration 1000 / 1500: loss 1.919764
# iteration 1100 / 1500: loss 1.973440
# iteration 1200 / 1500: loss 1.982049
# iteration 1300 / 1500: loss 1.962604
# iteration 1400 / 1500: loss 1.986038
# iteration 1499 / 1500: loss 2.029594
#
# ---------- 1.2e-06 9.7e+03 ----------
# iteration 0 / 1500: loss 306.443359
# iteration 100 / 1500: loss 4.238692
# iteration 200 / 1500: loss 2.000075
# iteration 300 / 1500: loss 2.018930
# iteration 400 / 1500: loss 1.998742
# iteration 500 / 1500: loss 2.079066
# iteration 600 / 1500: loss 1.990587
# iteration 700 / 1500: loss 1.971437
# iteration 800 / 1500: loss 1.940688
# iteration 900 / 1500: loss 1.967709
# iteration 1000 / 1500: loss 1.999599
# iteration 1100 / 1500: loss 2.002205
# iteration 1200 / 1500: loss 2.011258
# iteration 1300 / 1500: loss 2.080798
# iteration 1400 / 1500: loss 1.986414
# iteration 1499 / 1500: loss 2.034301
#
# ---------- 1.2e-06 1.3e+04 ----------
# iteration 0 / 1500: loss 427.009280
# iteration 100 / 1500: loss 2.379605
# iteration 200 / 1500: loss 2.050459
# iteration 300 / 1500: loss 2.070485
# iteration 400 / 1500: loss 2.101162
# iteration 500 / 1500: loss 2.139776
# iteration 600 / 1500: loss 2.020801
# iteration 700 / 1500: loss 2.046401
# iteration 800 / 1500: loss 1.973095
# iteration 900 / 1500: loss 1.990099
# iteration 1000 / 1500: loss 2.069447
# iteration 1100 / 1500: loss 2.110802
# iteration 1200 / 1500: loss 2.074111
# iteration 1300 / 1500: loss 2.010385
# iteration 1400 / 1500: loss 1.988717
# iteration 1499 / 1500: loss 2.033064
#
# ---------- 1.2e-06 1.9e+04 ----------
# iteration 0 / 1500: loss 570.152821
# iteration 100 / 1500: loss 2.099885
# iteration 200 / 1500: loss 2.091838
# iteration 300 / 1500: loss 2.093056
# iteration 400 / 1500: loss 2.080539
# iteration 500 / 1500: loss 2.086155
# iteration 600 / 1500: loss 2.031970
# iteration 700 / 1500: loss 2.132907
# iteration 800 / 1500: loss 2.093316
# iteration 900 / 1500: loss 2.102397
# iteration 1000 / 1500: loss 2.168748
# iteration 1100 / 1500: loss 2.096796
# iteration 1200 / 1500: loss 2.077103
# iteration 1300 / 1500: loss 2.055633
# iteration 1400 / 1500: loss 2.067536
# iteration 1499 / 1500: loss 2.038345
#
# ---------- 1.2e-06 2.6e+04 ----------
# iteration 0 / 1500: loss 802.423624
# iteration 100 / 1500: loss 2.129725
# iteration 200 / 1500: loss 2.134145
# iteration 300 / 1500: loss 2.107017
# iteration 400 / 1500: loss 2.087227
# iteration 500 / 1500: loss 2.107379
# iteration 600 / 1500: loss 2.112450
# iteration 700 / 1500: loss 2.085099
# iteration 800 / 1500: loss 2.093225
# iteration 900 / 1500: loss 2.142419
# iteration 1000 / 1500: loss 2.129478
# iteration 1100 / 1500: loss 2.098778
# iteration 1200 / 1500: loss 2.051702
# iteration 1300 / 1500: loss 2.103542
# iteration 1400 / 1500: loss 2.044374
# iteration 1499 / 1500: loss 2.164596
#
# ---------- 1.2e-06 3.6e+04 ----------
# iteration 0 / 1500: loss 1121.278137
# iteration 100 / 1500: loss 2.079892
# iteration 200 / 1500: loss 2.103067
# iteration 300 / 1500: loss 2.127895
# iteration 400 / 1500: loss 2.158692
# iteration 500 / 1500: loss 2.129939
# iteration 600 / 1500: loss 2.107157
# iteration 700 / 1500: loss 2.095889
# iteration 800 / 1500: loss 2.115601
# iteration 900 / 1500: loss 2.095802
# iteration 1000 / 1500: loss 2.082683
# iteration 1100 / 1500: loss 2.158950
# iteration 1200 / 1500: loss 2.158990
# iteration 1300 / 1500: loss 2.094413
# iteration 1400 / 1500: loss 2.201228
# iteration 1499 / 1500: loss 2.137043
#
# ---------- 1.2e-06 5.0e+04 ----------
# iteration 0 / 1500: loss 1553.910987
# iteration 100 / 1500: loss 2.180113
# iteration 200 / 1500: loss 2.225479
# iteration 300 / 1500: loss 2.216952
# iteration 400 / 1500: loss 2.171594
# iteration 500 / 1500: loss 2.150481
# iteration 600 / 1500: loss 2.183702
# iteration 700 / 1500: loss 2.152134
# iteration 800 / 1500: loss 2.191330
# iteration 900 / 1500: loss 2.158399
# iteration 1000 / 1500: loss 2.144132
# iteration 1100 / 1500: loss 2.104697
# iteration 1200 / 1500: loss 2.145232
# iteration 1300 / 1500: loss 2.201527
# iteration 1400 / 1500: loss 2.142547
# iteration 1499 / 1500: loss 2.175402
#
# ---------- 1.5e-06 7.0e+03 ----------
# iteration 0 / 1500: loss 221.483711
# iteration 100 / 1500: loss 4.987352
# iteration 200 / 1500: loss 2.061180
# iteration 300 / 1500: loss 2.021132
# iteration 400 / 1500: loss 1.992998
# iteration 500 / 1500: loss 2.064021
# iteration 600 / 1500: loss 1.908344
# iteration 700 / 1500: loss 1.949603
# iteration 800 / 1500: loss 2.060924
# iteration 900 / 1500: loss 1.942455
# iteration 1000 / 1500: loss 1.913909
# iteration 1100 / 1500: loss 1.992090
# iteration 1200 / 1500: loss 2.024994
# iteration 1300 / 1500: loss 1.942012
# iteration 1400 / 1500: loss 2.049524
# iteration 1499 / 1500: loss 2.012497
#
# ---------- 1.5e-06 9.7e+03 ----------
# iteration 0 / 1500: loss 306.490777
# iteration 100 / 1500: loss 2.773161
# iteration 200 / 1500: loss 1.965309
# iteration 300 / 1500: loss 2.055751
# iteration 400 / 1500: loss 1.959774
# iteration 500 / 1500: loss 2.027784
# iteration 600 / 1500: loss 2.088200
# iteration 700 / 1500: loss 2.081634
# iteration 800 / 1500: loss 1.996184
# iteration 900 / 1500: loss 2.090188
# iteration 1000 / 1500: loss 2.028896
# iteration 1100 / 1500: loss 1.996949
# iteration 1200 / 1500: loss 2.031393
# iteration 1300 / 1500: loss 2.001245
# iteration 1400 / 1500: loss 1.969012
# iteration 1499 / 1500: loss 2.075128
#
# ---------- 1.5e-06 1.3e+04 ----------
# iteration 0 / 1500: loss 420.824587
# iteration 100 / 1500: loss 2.160056
# iteration 200 / 1500: loss 2.048337
# iteration 300 / 1500: loss 2.056321
# iteration 400 / 1500: loss 2.092457
# iteration 500 / 1500: loss 2.010663
# iteration 600 / 1500: loss 2.052181
# iteration 700 / 1500: loss 2.033063
# iteration 800 / 1500: loss 2.074721
# iteration 900 / 1500: loss 2.061262
# iteration 1000 / 1500: loss 2.033549
# iteration 1100 / 1500: loss 2.038498
# iteration 1200 / 1500: loss 2.034753
# iteration 1300 / 1500: loss 1.999825
# iteration 1400 / 1500: loss 2.004633
# iteration 1499 / 1500: loss 2.010090
#
# ---------- 1.5e-06 1.9e+04 ----------
# iteration 0 / 1500: loss 575.748795
# iteration 100 / 1500: loss 2.047942
# iteration 200 / 1500: loss 2.106900
# iteration 300 / 1500: loss 2.033372
# iteration 400 / 1500: loss 2.083455
# iteration 500 / 1500: loss 2.064774
# iteration 600 / 1500: loss 2.014600
# iteration 700 / 1500: loss 2.127828
# iteration 800 / 1500: loss 2.104803
# iteration 900 / 1500: loss 2.119483
# iteration 1000 / 1500: loss 2.053478
# iteration 1100 / 1500: loss 2.117903
# iteration 1200 / 1500: loss 2.194825
# iteration 1300 / 1500: loss 2.100993
# iteration 1400 / 1500: loss 2.154692
# iteration 1499 / 1500: loss 1.993837
#
# ---------- 1.5e-06 2.6e+04 ----------
# iteration 0 / 1500: loss 799.154750
# iteration 100 / 1500: loss 1.999048
# iteration 200 / 1500: loss 2.022728
# iteration 300 / 1500: loss 2.049443
# iteration 400 / 1500: loss 2.032602
# iteration 500 / 1500: loss 2.042722
# iteration 600 / 1500: loss 2.167355
# iteration 700 / 1500: loss 2.140460
# iteration 800 / 1500: loss 2.076123
# iteration 900 / 1500: loss 2.096438
# iteration 1000 / 1500: loss 2.132703
# iteration 1100 / 1500: loss 2.111548
# iteration 1200 / 1500: loss 2.133580
# iteration 1300 / 1500: loss 2.136754
# iteration 1400 / 1500: loss 2.141320
# iteration 1499 / 1500: loss 2.192467
#
# ---------- 1.5e-06 3.6e+04 ----------
# iteration 0 / 1500: loss 1111.038158
# iteration 100 / 1500: loss 2.099873
# iteration 200 / 1500: loss 2.106397
# iteration 300 / 1500: loss 2.096837
# iteration 400 / 1500: loss 2.116109
# iteration 500 / 1500: loss 2.081175
# iteration 600 / 1500: loss 2.091757
# iteration 700 / 1500: loss 2.125931
# iteration 800 / 1500: loss 2.139730
# iteration 900 / 1500: loss 2.077252
# iteration 1000 / 1500: loss 2.170478
# iteration 1100 / 1500: loss 2.181651
# iteration 1200 / 1500: loss 2.146160
# iteration 1300 / 1500: loss 2.131070
# iteration 1400 / 1500: loss 2.158445
# iteration 1499 / 1500: loss 2.137084
#
# ---------- 1.5e-06 5.0e+04 ----------
# iteration 0 / 1500: loss 1551.481892
# iteration 100 / 1500: loss 2.183882
# iteration 200 / 1500: loss 2.162056
# iteration 300 / 1500: loss 2.176627
# iteration 400 / 1500: loss 2.165102
# iteration 500 / 1500: loss 2.119833
# iteration 600 / 1500: loss 2.139781
# iteration 700 / 1500: loss 2.158634
# iteration 800 / 1500: loss 2.133706
# iteration 900 / 1500: loss 2.159694
# iteration 1000 / 1500: loss 2.144526
# iteration 1100 / 1500: loss 2.143779
# iteration 1200 / 1500: loss 2.200467
# iteration 1300 / 1500: loss 2.145339
# iteration 1400 / 1500: loss 2.144589
# iteration 1499 / 1500: loss 2.148602
# It took 568.3 seconds.
# lr 5.000000e-07 reg 7.000000e+03 train accuracy: 0.365755 val accuracy: 0.380000
# lr 5.000000e-07 reg 9.714267e+03 train accuracy: 0.352061 val accuracy: 0.357000
# lr 5.000000e-07 reg 1.348100e+04 train accuracy: 0.337714 val accuracy: 0.353000
# lr 5.000000e-07 reg 1.870829e+04 train accuracy: 0.331204 val accuracy: 0.340000
# lr 5.000000e-07 reg 2.596247e+04 train accuracy: 0.316347 val accuracy: 0.329000
# lr 5.000000e-07 reg 3.602948e+04 train accuracy: 0.317592 val accuracy: 0.330000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.297510 val accuracy: 0.314000
# lr 6.004685e-07 reg 7.000000e+03 train accuracy: 0.362286 val accuracy: 0.383000
# lr 6.004685e-07 reg 9.714267e+03 train accuracy: 0.353429 val accuracy: 0.363000
# lr 6.004685e-07 reg 1.348100e+04 train accuracy: 0.330510 val accuracy: 0.337000
# lr 6.004685e-07 reg 1.870829e+04 train accuracy: 0.334408 val accuracy: 0.350000
# lr 6.004685e-07 reg 2.596247e+04 train accuracy: 0.328000 val accuracy: 0.342000
# lr 6.004685e-07 reg 3.602948e+04 train accuracy: 0.303796 val accuracy: 0.311000
# lr 6.004685e-07 reg 5.000000e+04 train accuracy: 0.293490 val accuracy: 0.306000
# lr 7.211248e-07 reg 7.000000e+03 train accuracy: 0.365347 val accuracy: 0.377000
# lr 7.211248e-07 reg 9.714267e+03 train accuracy: 0.358000 val accuracy: 0.373000
# lr 7.211248e-07 reg 1.348100e+04 train accuracy: 0.346959 val accuracy: 0.351000
# lr 7.211248e-07 reg 1.870829e+04 train accuracy: 0.341776 val accuracy: 0.343000
# lr 7.211248e-07 reg 2.596247e+04 train accuracy: 0.309163 val accuracy: 0.324000
# lr 7.211248e-07 reg 3.602948e+04 train accuracy: 0.313122 val accuracy: 0.328000
# lr 7.211248e-07 reg 5.000000e+04 train accuracy: 0.297000 val accuracy: 0.305000
# lr 8.660254e-07 reg 7.000000e+03 train accuracy: 0.365898 val accuracy: 0.374000
# lr 8.660254e-07 reg 9.714267e+03 train accuracy: 0.336776 val accuracy: 0.351000
# lr 8.660254e-07 reg 1.348100e+04 train accuracy: 0.342000 val accuracy: 0.360000
# lr 8.660254e-07 reg 1.870829e+04 train accuracy: 0.330122 val accuracy: 0.341000
# lr 8.660254e-07 reg 2.596247e+04 train accuracy: 0.327102 val accuracy: 0.340000
# lr 8.660254e-07 reg 3.602948e+04 train accuracy: 0.302653 val accuracy: 0.325000
# lr 8.660254e-07 reg 5.000000e+04 train accuracy: 0.291531 val accuracy: 0.305000
# lr 1.040042e-06 reg 7.000000e+03 train accuracy: 0.360735 val accuracy: 0.375000
# lr 1.040042e-06 reg 9.714267e+03 train accuracy: 0.355878 val accuracy: 0.353000
# lr 1.040042e-06 reg 1.348100e+04 train accuracy: 0.336082 val accuracy: 0.339000
# lr 1.040042e-06 reg 1.870829e+04 train accuracy: 0.322163 val accuracy: 0.324000
# lr 1.040042e-06 reg 2.596247e+04 train accuracy: 0.321571 val accuracy: 0.339000
# lr 1.040042e-06 reg 3.602948e+04 train accuracy: 0.311551 val accuracy: 0.340000
# lr 1.040042e-06 reg 5.000000e+04 train accuracy: 0.299388 val accuracy: 0.306000
# lr 1.249025e-06 reg 7.000000e+03 train accuracy: 0.355204 val accuracy: 0.370000
# lr 1.249025e-06 reg 9.714267e+03 train accuracy: 0.353224 val accuracy: 0.359000
# lr 1.249025e-06 reg 1.348100e+04 train accuracy: 0.329816 val accuracy: 0.343000
# lr 1.249025e-06 reg 1.870829e+04 train accuracy: 0.318571 val accuracy: 0.341000
# lr 1.249025e-06 reg 2.596247e+04 train accuracy: 0.329571 val accuracy: 0.337000
# lr 1.249025e-06 reg 3.602948e+04 train accuracy: 0.292102 val accuracy: 0.312000
# lr 1.249025e-06 reg 5.000000e+04 train accuracy: 0.303612 val accuracy: 0.301000
# lr 1.500000e-06 reg 7.000000e+03 train accuracy: 0.353980 val accuracy: 0.366000
# lr 1.500000e-06 reg 9.714267e+03 train accuracy: 0.347714 val accuracy: 0.371000
# lr 1.500000e-06 reg 1.348100e+04 train accuracy: 0.332224 val accuracy: 0.343000
# lr 1.500000e-06 reg 1.870829e+04 train accuracy: 0.318592 val accuracy: 0.330000
# lr 1.500000e-06 reg 2.596247e+04 train accuracy: 0.312224 val accuracy: 0.323000
# lr 1.500000e-06 reg 3.602948e+04 train accuracy: 0.298388 val accuracy: 0.318000
# lr 1.500000e-06 reg 5.000000e+04 train accuracy: 0.278755 val accuracy: 0.289000
# best validation accuracy achieved during cross-validation: 0.383000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.358000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
# True. 새로 추가한 이미지의 SVM Loss $L_i$가 0 인 경우.
#
# 즉 $s_j - s_{y_i} + 1 <= 0$ 인 경우
#
# $\color{blue}{\textit Your Explanation:}$
#
# 새로 추가한 이미지의 $L_i$가 총 Loss sum에 영향을 주지 않으려면 0이 되어야 하고, 이는 곧 $s_j - s_{y_i} + 1 <= 0$ 이어야 함.
#
# 이 경우 해당 이미지의 SVM $L_i$는 0이 되고,
#
# Softmax $L_i$는 이론상 0이 나오려면 정답스코어 $s_{y_i}=\infty$ 혹은 오답스코어 $s_j=-\infty$가 되어야 하므로 불가능.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)

    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
